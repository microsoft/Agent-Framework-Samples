# %% [markdown]
# # 🔀 Conditional Agent Workflows with Azure AI Foundry (Python)
#
# ## 📋 Advanced Decision-Based Workflow Tutorial
#
# This notebook demonstrates **conditional workflow patterns** using Azure AI Foundry and the Microsoft Agent Framework. You'll learn how to build intelligent, decision-driven workflows that dynamically route processing based on content analysis, business rules, and AI-powered decision making.
#
# ## 🎯 Learning Objectives
#
# ### 🧠 **Intelligent Decision Making**
# - **Conditional Logic**: Implement dynamic branching based on AI analysis and business rules
# - **Content-Aware Routing**: Route workflow paths based on content analysis and classification
# - **Adaptive Processing**: Adjust workflow behavior based on real-time conditions and data
# - **Azure AI Integration**: Leverage Azure AI Foundry's advanced capabilities for decision making
#
# ### 🔀 **Advanced Workflow Patterns**
# - **Decision Trees**: Build complex decision structures with multiple branching points
# - **Rule-Based Processing**: Implement business logic and compliance requirements
# - **Dynamic Workflow Modification**: Adapt workflows based on runtime conditions
# - **Context-Aware Operations**: Make decisions based on accumulated workflow context
#
# ### 🏢 **Enterprise Conditional Applications**
# - **Document Classification**: Route documents to appropriate processing workflows
# - **Customer Service Triage**: Automatically route inquiries to specialized handling workflows
# - **Compliance Processing**: Apply different validation rules based on content type and regulations
# - **Quality Assurance**: Route content through different review processes based on quality metrics
#
# ## ⚙️ Prerequisites & Setup
#
# ### 📦 **Installation & Dependencies**
#
# This workflow requires specific installation steps for Azure AI Foundry integration:
#
# ```bash
#
# pip install agent-framework-azure-ai -U
# ```
#
# ### 🔑 **Azure AI Foundry Configuration**
#
# **Required Azure Resources:**
# - Azure AI Foundry workspace with appropriate models deployed
# - Azure subscription with necessary permissions
# - Azure CLI authentication configured
#
#
# **Authentication Setup:**
# ```bash
# # Azure CLI authentication
# az login
# az account set --subscription "your-subscription-id"
# azd auth login
# ```
#
# ### 🏗️ **Conditional Workflow Architecture**
#
# ```mermaid
# graph TD
#     A[Input Document/Request] --> B[Initial Analysis Agent]
#     B --> C{Decision Point}
#     C -->|Condition 1| D[Workflow Path A]
#     C -->|Condition 2| E[Workflow Path B]
#     C -->|Condition 3| F[Workflow Path C]
#     D --> G[Specialized Processing A]
#     E --> H[Specialized Processing B]
#     F --> I[Specialized Processing C]
#     G --> J[Result Integration]
#     H --> J
#     I --> J
#     J --> K[Final Output]
# ```
#
# **Key Components:**
# - **Analysis Agents**: AI agents that evaluate content and make routing decisions
# - **Decision Points**: Conditional logic that determines workflow paths
# - **Specialized Processors**: Different agents optimized for specific content types or scenarios
# - **Integration Layer**: Combines results from different workflow paths
#
# ## 🎨 **Conditional Workflow Design Patterns**
#
# ### 📋 **Document Processing Triage**
# ```
# Document Input → Content Analysis → Classification → Specialized Processing Workflow
# ```
#
# ### 🎯 **Customer Service Routing**
# ```
# Customer Inquiry → Intent Analysis → Urgency Assessment → Route to Specialist Team
# ```
#
# ### 🔍 **Quality Assurance Workflow**
# ```
# Content Input → Quality Metrics → Risk Assessment → Appropriate Review Process
# ```
#
# ### 📊 **Business Intelligence Pipeline**
# ```
# Data Input → Source Analysis → Processing Rules → Specialized Analytics Workflow
# ```
#
# ## 🏢 **Enterprise Benefits**
#
# ### 🎯 **Intelligent Automation**
# - **Smart Routing**: Automatically direct work to the most appropriate processing path
# - **Adaptive Behavior**: Workflows that learn and adapt based on patterns and outcomes
# - **Business Rule Integration**: Incorporate complex business logic and compliance requirements
# - **Context-Aware Processing**: Make decisions based on full workflow context and history
#
# ### 📈 **Operational Efficiency**
# - **Reduced Manual Intervention**: Automated decision making reduces need for human routing
# - **Specialized Processing**: Each workflow path optimized for specific scenarios
# - **Resource Optimization**: Efficient allocation of processing resources based on content type
# - **Faster Time-to-Resolution**: Direct routing to appropriate specialists and processes
#
# ### 🛡️ **Governance & Control**
# - **Audit Trails**: Complete logging of decision points and routing rationale
# - **Compliance Enforcement**: Automatic application of regulatory and policy requirements
# - **Risk Management**: Route high-risk content through enhanced security and review processes
# - **Quality Assurance**: Ensure appropriate level of review based on content characteristics
#
# ### 📊 **Analytics & Optimization**
# - **Decision Analytics**: Track effectiveness of routing decisions and workflow paths
# - **Performance Metrics**: Measure efficiency of different workflow branches
# - **Continuous Improvement**: Identify optimization opportunities in conditional logic
# - **Business Intelligence**: Gain insights into content patterns and processing requirements
#
# Let's build intelligent, decision-driven AI workflows! 🚀

# %%
####### Linux / MacOS Setup Instructions #######

####### Linux Instructions #######
# ! sudo apt update 
# ! sudo apt install graphviz -y

####### macOS Instructions #######
# ! brew install graphviz

# %%
# ! pip install -r ../../../Installation/requirements.txt -U

# %% [markdown]
# requirements.txt & constraints.txt - in ./Installation
#
# please copy .env.examples as .env

# %% [markdown]
# **Note** choose gpt-4.1-mini

# %%
import os

from dataclasses import dataclass
from typing_extensions import Literal
from pydantic import BaseModel

# %%
from azure.identity.aio import AzureCliCredential
from dotenv import load_dotenv

from agent_framework import HostedCodeInterpreterTool
from azure.ai.agents.models import CodeInterpreterTool
from agent_framework.azure import AzureAIProjectAgentProvider
from agent_framework import (
    AgentExecutor,
    AgentExecutorRequest,
    AgentExecutorResponse,
    ChatMessage,
    Role,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowEvent,
    executor,
    WorkflowViz
)

# %%
load_dotenv()
# Out:
# True

# %%
EvangelistInstructions = """
You are a technology evangelist create a first draft for a technical tutorials.
1. Each knowledge point in the outline must include a link. Follow the link to access the content related to the knowledge point in the outline. Expand on that content.
2. Each knowledge point must be explained in detail.
3. Rewrite the content according to the entry requirements, including the title, outline, and corresponding content. It is not necessary to follow the outline in full order.
4. The content must be more than 200 words.
4. Output draft as Markdown format. set 'draft_content' to the draft content.
5. return result as JSON with fields 'draft_content' (string).
"""

ContentReviewerInstructions = """
You are a content reviewer for a publishing company. You need to check whether the tutorial's draft content meets the following requirements:

1. The draft content less than 200 words, set 'review_result' to 'No' and 'reason' to 'Content is too short'. If the draft content is more than 200 words, set 'review_result' to 'Yes' and 'reason' to 'The content is good'.
2. set 'draft_content' to the original draft content.
3. return result as JSON with fields 'review_result' (one of Yes, No) and 'reason' (string) and 'draft_content' (string).

"""

PublisherInstructions = """
You are the content publisher ,run code to save the tutorial's draft content as a Markdown file. Saved file's name is marked with current date and time, such as yearmonthdayhourminsec. Note that if it is 1-9, you need to add 0, such as  20240101123045.md. 
"""

# %%
OUTLINE_Content ="""
# Introduce AI Agent


## What's AI Agent

https://github.com/microsoft/ai-agents-for-beginners/tree/main/01-intro-to-ai-agents


***Note*** Don's create any sample code 


## Introduce Azure AI Foundry Agent Service 

https://learn.microsoft.com/en-us/azure/ai-foundry/agents/overview


***Note*** Don's create any sample code 


## Microsoft Agent Framework 

https://github.com/microsoft/agent-framework/tree/main/docs/docs-templates


***Note*** Don's create any sample code 
"""

# %%
# Note: Tools are now configured inline when creating agents

# %%
class EvangelistAgent(BaseModel):
    draft_content: str

class ReviewAgent(BaseModel):
    review_result: Literal["Yes", "No"]
    reason: str
    draft_content: str

class PublisherAgent(BaseModel):
    file_path: str

@dataclass
class ReviewResult:
    review_result: str
    reason: str
    draft_content: str

@executor(id="to_reviewer_result")
async def to_reviewer_result(response: AgentExecutorResponse, ctx: WorkflowContext[ReviewResult]) -> None:
    # Get the last message text from the response
    response_text = response.agent_response.text.strip()
    print(f"Raw response from reviewer agent: {response_text}")

    parsed = ReviewAgent.model_validate_json(response_text)
    await ctx.send_message(
        ReviewResult(
            review_result=parsed.review_result,
            reason=parsed.reason,
            draft_content=parsed.draft_content,
        )
    )


def select_targets(review: ReviewResult, target_ids: list[str]) -> list[str]:
        # Order: [handle_review, submit_to_email_assistant, summarize_email, handle_uncertain]
        handle_review_id, save_draft_id = target_ids
        if review.review_result == "Yes":
            return [save_draft_id]
        else:
            return [handle_review_id]
        


@executor(id="handle_review")
async def handle_review(review: ReviewResult, ctx: WorkflowContext[str]) -> None:
    if review.review_result == "No":
        await ctx.yield_output(f"Review failed: {review.reason}, please revise the draft.")
    else:
        await ctx.send_message(
            AgentExecutorRequest(messages=[ChatMessage(Role.USER, text=review.draft_content)], should_respond=True)
        )


@executor(id="save_draft")
async def save_draft(review: ReviewResult, ctx: WorkflowContext[AgentExecutorRequest]) -> None:
    # Only called for long NotSpam emails by selection_func
    await ctx.send_message(
        AgentExecutorRequest(messages=[ChatMessage(Role.USER, text=review.draft_content)], should_respond=True)
    )

# %%
from IPython.display import SVG, display, HTML

# %%
class DatabaseEvent(WorkflowEvent): ...

# %%
async with (
        AzureCliCredential() as credential,
        AzureAIProjectAgentProvider(project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"], credential=credential) as client,
    ):  
        try:
                evangelist_agent_obj = await client.create_agent(
                    name="evangelist-agent",
                    instructions=EvangelistInstructions,
                    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
                    tools=[
                        {
                            "type": "bing_grounding",
                            "bing_grounding": {
                                "search_configurations": [
                                    {
                                        "project_connection_id": os.environ["BING_CONNECTION_ID"],
                                    }
                                ]
                            },
                        }
                    ],
                    # response_format=EvangelistAgent
                )
                evangelist_agent = AgentExecutor(evangelist_agent_obj, id="evangelist_agent")
                
                reviewer_agent_obj = await client.create_agent(
                    name="reviewer-agent",
                    instructions=ContentReviewerInstructions,
                    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
                    # response_format=ReviewAgent
                )
                reviewer_agent = AgentExecutor(reviewer_agent_obj, id="reviewer_agent")
                
                publisher_agent_obj = await client.create_agent(
                    name="publisher-agent",
                    instructions=PublisherInstructions,
                    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
                    tools=HostedCodeInterpreterTool()
                    # response_format=PublisherAgent
                )
                publisher_agent = AgentExecutor(publisher_agent_obj, id="publisher_agent")

                workflow = (
                    WorkflowBuilder()
                        .set_start_executor(evangelist_agent)
                        .add_edge(evangelist_agent, reviewer_agent)
                        .add_edge(reviewer_agent, to_reviewer_result)
                        .add_multi_selection_edge_group(
                            to_reviewer_result,
                            [handle_review, save_draft],
                            selection_func=select_targets,
                        )
                        .add_edge(save_draft, publisher_agent)
                        .build()
                )

                # workflow = SequentialBuilder().participants([evangelist_chat_agent, reviewer_chat_agent, publisher_chat_agent]).build()
                print("Generating workflow visualization...")
                viz = WorkflowViz(workflow)
                # Print out the mermaid string.
                print("Mermaid string: \n=======")
                print(viz.to_mermaid())
                print("=======")
                # Print out the DiGraph string.
                print("DiGraph string: \n=======")
                print(viz.to_digraph())
                print("=======")
                svg_file = viz.export(format="svg")
                print(f"SVG file saved to: {svg_file}")

                if svg_file and os.path.exists(svg_file):
                    try:
                        # Preferred: direct SVG rendering
                        display(SVG(filename=svg_file))
                    except Exception as e:
                        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
                        try:
                            with open(svg_file, "r", encoding="utf-8") as f:
                                svg_text = f.read()
                            display(HTML(svg_text))
                        except Exception as inner:
                            print(f"❌ Fallback HTML render also failed: {inner}")
                else:
                    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

                
                task = """
                    You are a evangelist , need to write a  draft based on the following outline and the content provided in the link corresponding to the outline. After draft create , the reviewer check it , if it meets the requirements, it will be submitted to the publisher and save it as a Markdown file, otherwise need to rewrite draft until it meets the requirements.
                        The provided outline content and related links is as follows:

                    """ + OUTLINE_Content

                
                async for event in workflow.run_stream(task):
                    if isinstance(event, DatabaseEvent):
                        print(f"{event}")
                    if isinstance(event, WorkflowEvent):
                        print(f"Workflow output: {event.data}")



        finally:
            print("done")
# Out:
# Generating workflow visualization...
# Mermaid string:
# =======
# flowchart TD
#   evangelist_agent["evangelist_agent (Start)"];
#   reviewer_agent["reviewer_agent"];
#   to_reviewer_result["to_reviewer_result"];
#   handle_review["handle_review"];
#   save_draft["save_draft"];
#   publisher_agent["publisher_agent"];
#   evangelist_agent --> reviewer_agent;
#   reviewer_agent --> to_reviewer_result;
#   to_reviewer_result --> handle_review;
#   to_reviewer_result --> save_draft;
#   save_draft --> publisher_agent;
# =======
# DiGraph string:
# =======
# digraph Workflow {
#   rankdir=TD;
#   node [shape=box, style=filled, fillcolor=lightblue];
#   edge [color=black, arrowhead=vee];
#
#   "evangelist_agent" [fillcolor=lightgreen, label="evangelist_agent\n(Start)"];
#   "reviewer_agent" [label="reviewer_agent"];
#   "to_reviewer_result" [label="to_reviewer_result"];
#   "handle_review" [label="handle_review"];
#   "save_draft" [label="save_draft"];
#   "publisher_agent" [label="publisher_agent"];
#   "evangelist_agent" -> "reviewer_agent";
#   "reviewer_agent" -> "to_reviewer_result";
#   "to_reviewer_result" -> "handle_review";
#   "to_reviewer_result" -> "save_draft";
#   "save_draft" -> "publisher_agent";
# }
# =======
# SVG file saved to: /var/folders/66/m82q566n4c130x_vdtybj5b40000gn/T/tmp9qhb7i32.svg
# Workflow output: None
# Workflow output: None
# Workflow output:
#                     You are a evangelist , need to write a  draft based on the following outline and the content provided in the link corresponding to the outline. After draft create , the reviewer check it , if it meets the requirements, it will be submitted to the publisher and save it as a Markdown file, otherwise need to rewrite draft until it meets the requirements.
#                         The provided outline content and related links is as follows:
#
#
# # Introduce AI Agent
#
#
# ## What's AI Agent
#
# https://github.com/microsoft/ai-agents-for-beginners/tree/main/01-intro-to-ai-agents
#
#
# ***Note*** Don's create any sample code
#
#
# ## Introduce Azure AI Foundry Agent Service
#
# https://learn.microsoft.com/en-us/azure/ai-foundry/agents/overview
#
#
# ***Note*** Don's create any sample code
#
#
# ## Microsoft Agent Framework
#
# https://github.com/microsoft/agent-framework/tree/main/docs/docs-templates
#
#
# ***Note*** Don's create any sample code
#
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output: {
#
# Workflow output:
# Workflow output:  "
# Workflow output: draft
# Workflow output: _content
# Workflow output: ":
# Workflow output:  "#
# Workflow output:  Introducing
# Workflow output:  AI
# Workflow output:  Agents
# Workflow output: :
# Workflow output:  Empower
# Workflow output: ing
# Workflow output:  Intelligent
# Workflow output:  Automation
# Workflow output: \n
# Workflow output: \n
# Workflow output: ##
# Workflow output:  What's
# Workflow output:  an
# Workflow output:  AI
# Workflow output:  Agent
# Workflow output: ?\
# Workflow output: n
# Workflow output: \n
# Workflow output: An
# Workflow output:  AI
# Workflow output:  Agent
# Workflow output:  is
# Workflow output:  a
# Workflow output:  software
# Workflow output:  entity
# Workflow output:  designed
# Workflow output:  to
# Workflow output:  autonom
# Workflow output: ously
# Workflow output:  perform
# Workflow output:  tasks
# Workflow output:  or
# Workflow output:  services
# Workflow output:  on
# Workflow output:  behalf
# Workflow output:  of
# Workflow output:  a
# Workflow output:  user
# Workflow output:  or
# Workflow output:  system
# Workflow output:  by
# Workflow output:  leveraging
# Workflow output:  artificial
# Workflow output:  intelligence
# Workflow output:  technologies
# Workflow output: .
# Workflow output:  These
# Workflow output:  agents
# Workflow output:  continuously
# Workflow output:  perceive
# Workflow output:  their
# Workflow output:  environment
# Workflow output: ,
# Workflow output:  make
# Workflow output:  decisions
# Workflow output:  based
# Workflow output:  on
# Workflow output:  the
# Workflow output:  information
# Workflow output:  available
# Workflow output: ,
# Workflow output:  and
# Workflow output:  act
# Workflow output:  towards
# Workflow output:  achieving
# Workflow output:  specific
# Workflow output:  goals
# Workflow output:  without
# Workflow output:  constant
# Workflow output:  human
# Workflow output:  intervention
# Workflow output: .
# Workflow output:  AI
# Workflow output:  Agents
# Workflow output:  can
# Workflow output:  range
# Workflow output:  from
# Workflow output:  simple
# Workflow output:  rule
# Workflow output: -based
# Workflow output:  systems
# Workflow output:  to
# Workflow output:  highly
# Workflow output:  complex
# Workflow output:  entities
# Workflow output:  that
# Workflow output:  use
# Workflow output:  machine
# Workflow output:  learning
# Workflow output: ,
# Workflow output:  natural
# Workflow output:  language
# Workflow output:  processing
# Workflow output: ,
# Workflow output:  and
# Workflow output:  reasoning
# Workflow output:  to
# Workflow output:  handle
# Workflow output:  dynamic
# Workflow output:  and
# Workflow output:  uncertain
# Workflow output:  environments
# Workflow output: .
# Workflow output:  They
# Workflow output:  effectively
# Workflow output:  streamline
# Workflow output:  workflows
# Workflow output: ,
# Workflow output:  enhance
# Workflow output:  decision
# Workflow output: -making
# Workflow output: ,
# Workflow output:  and
# Workflow output:  enable
# Workflow output:  scalable
# Workflow output:  automation
# Workflow output:  in
# Workflow output:  various
# Workflow output:  domains
# Workflow output: .\
# Workflow output: n
# Workflow output: \n
# Workflow output: The
# Workflow output:  fundamental
# Workflow output:  concept
# Workflow output:  of
# Workflow output:  AI
# Workflow output:  Agents
# Workflow output:  revolves
# Workflow output:  around
# Workflow output:  their
# Workflow output:  capability
# Workflow output:  to
# Workflow output:  understand
# Workflow output:  commands
# Workflow output: ,
# Workflow output:  learn
# Workflow output:  from
# Workflow output:  data
# Workflow output:  or
# Workflow output:  interactions
# Workflow output: ,
# Workflow output:  adapt
# Workflow output:  to
# Workflow output:  new
# Workflow output:  circumstances
# Workflow output: ,
# Workflow output:  and
# Workflow output:  proactively
# Workflow output:  execute
# Workflow output:  tasks
# Workflow output: .
# Workflow output:  This
# Workflow output:  autonomy
# Workflow output:  reduces
# Workflow output:  the
# Workflow output:  burden
# Workflow output:  on
# Workflow output:  human
# Workflow output:  operators
# Workflow output:  and
# Workflow output:  fosters
# Workflow output:  efficiency
# Workflow output:  by
# Workflow output:  allowing
# Workflow output:  intelligent
# Workflow output:  systems
# Workflow output:  to
# Workflow output:  manage
# Workflow output:  routine
# Workflow output: ,
# Workflow output:  repetitive
# Workflow output: ,
# Workflow output:  or
# Workflow output:  complex
# Workflow output:  activities
# Workflow output: .
# Workflow output:  You
# Workflow output:  can
# Workflow output:  explore
# Workflow output:  more
# Workflow output:  about
# Workflow output:  the
# Workflow output:  basics
# Workflow output:  and
# Workflow output:  how
# Workflow output:  AI
# Workflow output:  Agents
# Workflow output:  function
# Workflow output:  in
# Workflow output:  different
# Workflow output:  contexts
# Workflow output:  on
# Workflow output:  the
# Workflow output:  [
# Workflow output: AI
# Workflow output:  Agents
# Workflow output:  for
# Workflow output:  Beginners
# Workflow output:  repository
# Workflow output: ](
# Workflow output: https
# Workflow output: ://
# Workflow output: github
# Workflow output: .com
# Workflow output: /m
# Workflow output: icrosoft
# Workflow output: /
# Workflow output: ai
# Workflow output: -ag
# Workflow output: ents
# Workflow output: -for
# Workflow output: -b
# Workflow output: eg
# Workflow output: inners
# Workflow output: /tree
# Workflow output: /main
# Workflow output: /
# Workflow output: 01
# Workflow output: -int
# Workflow output: ro
# Workflow output: -to
# Workflow output: -ai
# Workflow output: -ag
# Workflow output: ents
# Workflow output: ).\
# Workflow output: n
# Workflow output: \n
# Workflow output: \n
# Workflow output: ##
# Workflow output:  Introducing
# Workflow output:  Azure
# Workflow output:  AI
# Workflow output:  Found
# Workflow output: ry
# Workflow output:  Agent
# Workflow output:  Service
# Workflow output: \n
# Workflow output: \n
# Workflow output: Azure
# Workflow output:  AI
# Workflow output:  Found
# Workflow output: ry
# Workflow output:  Agent
# Workflow output:  Service
# Workflow output:  is
# Workflow output:  a
# Workflow output:  breakthrough
# Workflow output:  cloud
# Workflow output: -based
# Workflow output:  platform
# Workflow output:  from
# Workflow output:  Microsoft
# Workflow output:  designed
# Workflow output:  to
# Workflow output:  build
# Workflow output: ,
# Workflow output:  deploy
# Workflow output: ,
# Workflow output:  and
# Workflow output:  manage
# Workflow output:  sophisticated
# Workflow output:  AI
# Workflow output:  Agents
# Workflow output:  at
# Workflow output:  scale
# Workflow output: .
# Workflow output:  This
# Workflow output:  service
# Workflow output:  empowers
# Workflow output:  developers
# Workflow output:  and
# Workflow output:  organizations
# Workflow output:  to
# Workflow output:  create
# Workflow output:  intelligent
# Workflow output:  agents
# Workflow output:  that
# Workflow output:  integrate
# Workflow output:  seamlessly
# Workflow output:  with
# Workflow output:  existing
# Workflow output:  enterprise
# Workflow output:  systems
# Workflow output:  while
# Workflow output:  benefiting
# Workflow output:  from
# Workflow output:  Azure
# Workflow output: 's
# Workflow output:  robust
# Workflow output:  infrastructure
# Workflow output: ,
# Workflow output:  security
# Workflow output: ,
# Workflow output:  and
# Workflow output:  AI
# Workflow output:  capabilities
# Workflow output: .\
# Workflow output: n
# Workflow output: \n
# Workflow output: The
# Workflow output:  Found
# Workflow output: ry
# Workflow output:  Agent
# Workflow output:  Service
# Workflow output:  simplifies
# Workflow output:  the
# Workflow output:  lifecycle
# Workflow output:  management
# Workflow output:  of
# Workflow output:  AI
# Workflow output:  Agents
# Workflow output:  through
# Workflow output:  features
# Workflow output:  like
# Workflow output:  version
# Workflow output:  control
# Workflow output: ,
# Workflow output:  environment
# Workflow output:  consistency
# Workflow output: ,
# Workflow output:  and
# Workflow output:  monitoring
# Workflow output: ,
# Workflow output:  all
# Workflow output:  hosted
# Workflow output:  on
# Workflow output:  Azure
# Workflow output: .
# Workflow output:  It
# Workflow output:  supports
# Workflow output:  multi
# Workflow output: -modal
# Workflow output:  interactions
# Workflow output: ,
# Workflow output:  enabling
# Workflow output:  agents
# Workflow output:  to
# Workflow output:  process
# Workflow output:  natural
# Workflow output:  language
# Workflow output: ,
# Workflow output:  handle
# Workflow output:  complex
# Workflow output:  workflows
# Workflow output: ,
# Workflow output:  and
# Workflow output:  make
# Workflow output:  real
# Workflow output: -time
# Workflow output:  decisions
# Workflow output: .
# Workflow output:  With
# Workflow output:  this
# Workflow output:  service
# Workflow output: ,
# Workflow output:  businesses
# Workflow output:  can
# Workflow output:  accelerate
# Workflow output:  the
# Workflow output:  deployment
# Workflow output:  of
# Workflow output:  AI
# Workflow output: -driven
# Workflow output:  solutions
# Workflow output:  that
# Workflow output:  optimize
# Workflow output:  customer
# Workflow output:  engagement
# Workflow output: ,
# Workflow output:  automate
# Workflow output:  operations
# Workflow output: ,
# Workflow output:  and
# Workflow output:  enhance
# Workflow output:  analytics
# Workflow output: .\
# Workflow output: n
# Workflow output: \n
# Workflow output: Additionally
# Workflow output: ,
# Workflow output:  Azure
# Workflow output:  AI
# Workflow output:  Found
# Workflow output: ry
# Workflow output:  provides
# Workflow output:  extens
# Workflow output: ibility
# Workflow output:  and
# Workflow output:  integration
# Workflow output:  options
# Workflow output: ,
# Workflow output:  making
# Workflow output:  it
# Workflow output:  suitable
# Workflow output:  for
# Workflow output:  diverse
# Workflow output:  industries
# Workflow output:  ranging
# Workflow output:  from
# Workflow output:  finance
# Workflow output:  and
# Workflow output:  healthcare
# Workflow output:  to
# Workflow output:  retail
# Workflow output:  and
# Workflow output:  manufacturing
# Workflow output: .
# Workflow output:  For
# Workflow output:  an
# Workflow output:  in
# Workflow output: -depth
# Workflow output:  look
# Workflow output:  at
# Workflow output:  the
# Workflow output:  service
# Workflow output: ’s
# Workflow output:  capabilities
# Workflow output: ,
# Workflow output:  architecture
# Workflow output: ,
# Workflow output:  and
# Workflow output:  getting
# Workflow output:  started
# Workflow output:  guide
# Workflow output: ,
# Workflow output:  please
# Workflow output:  visit
# Workflow output:  the
# Workflow output:  official
# Workflow output:  [
# Workflow output: Azure
# Workflow output:  AI
# Workflow output:  Found
# Workflow output: ry
# Workflow output:  Agent
# Workflow output:  Service
# Workflow output:  overview
# Workflow output: ](
# Workflow output: https
# Workflow output: ://
# Workflow output: learn
# Workflow output: .microsoft
# Workflow output: .com
# Workflow output: /en
# Workflow output: -us
# Workflow output: /
# Workflow output: azure
# Workflow output: /
# Workflow output: ai
# Workflow output: -found
# Workflow output: ry
# Workflow output: /
# Workflow output: agents
# Workflow output: /
# Workflow output: overview
# Workflow output: ).\
# Workflow output: n
# Workflow output: \n
# Workflow output: \n
# Workflow output: ##
# Workflow output:  Microsoft
# Workflow output:  Agent
# Workflow output:  Framework
# Workflow output: \n
# Workflow output: \n
# Workflow output: The
# Workflow output:  Microsoft
# Workflow output:  Agent
# Workflow output:  Framework
# Workflow output:  is
# Workflow output:  an
# Workflow output:  open
# Workflow output: -source
# Workflow output:  initiative
# Workflow output:  that
# Workflow output:  provides
# Workflow output:  a
# Workflow output:  comprehensive
# Workflow output:  set
# Workflow output:  of
# Workflow output:  tools
# Workflow output: ,
# Workflow output:  SDK
# Workflow output: s
# Workflow output: ,
# Workflow output:  and
# Workflow output:  documentation
# Workflow output:  for
# Workflow output:  developing
# Workflow output:  AI
# Workflow output:  Agents
# Workflow output: .
# Workflow output:  It
# Workflow output:  stream
# Workflow output: lines
# Workflow output:  the
# Workflow output:  creation
# Workflow output:  of
# Workflow output:  intelligent
# Workflow output:  applications
# Workflow output:  by
# Workflow output:  offering
# Workflow output:  modular
# Workflow output:  components
# Workflow output: ,
# Workflow output:  reusable
# Workflow output:  templates
# Workflow output: ,
# Workflow output:  and
# Workflow output:  developer
# Workflow output: -friendly
# Workflow output:  interfaces
# Workflow output: .\
# Workflow output: n
# Workflow output: \n
# Workflow output: This
# Workflow output:  framework
# Workflow output:  supports
# Workflow output:  the
# Workflow output:  seamless
# Workflow output:  integration
# Workflow output:  of
# Workflow output:  AI
# Workflow output:  Agents
# Workflow output:  with
# Workflow output:  diverse
# Workflow output:  communication
# Workflow output:  channels
# Workflow output: ,
# Workflow output:  including
# Workflow output:  chat
# Workflow output: ,
# Workflow output:  voice
# Workflow output: ,
# Workflow output:  and
# Workflow output:  messaging
# Workflow output:  platforms
# Workflow output: ,
# Workflow output:  enabling
# Workflow output:  rich
# Workflow output:  and
# Workflow output:  interactive
# Workflow output:  user
# Workflow output:  experiences
# Workflow output: .
# Workflow output:  The
# Workflow output:  modular
# Workflow output:  design
# Workflow output:  promotes
# Workflow output:  scalability
# Workflow output:  and
# Workflow output:  adaptability
# Workflow output: ,
# Workflow output:  helping
# Workflow output:  developers
# Workflow output:  to
# Workflow output:  customize
# Workflow output:  agents
# Workflow output:  to
# Workflow output:  specific
# Workflow output:  business
# Workflow output:  needs
# Workflow output:  without
# Workflow output:  building
# Workflow output:  everything
# Workflow output:  from
# Workflow output:  scratch
# Workflow output: .\
# Workflow output: n
# Workflow output: \n
# Workflow output: Moreover
# Workflow output: ,
# Workflow output:  the
# Workflow output:  Microsoft
# Workflow output:  Agent
# Workflow output:  Framework
# Workflow output:  emphasizes
# Workflow output:  best
# Workflow output:  practices
# Workflow output:  for
# Workflow output:  security
# Workflow output: ,
# Workflow output:  compliance
# Workflow output: ,
# Workflow output:  and
# Workflow output:  performance
# Workflow output:  optimization
# Workflow output: ,
# Workflow output:  ensuring
# Workflow output:  that
# Workflow output:  enterprise
# Workflow output: -grade
# Workflow output:  AI
# Workflow output:  Agents
# Workflow output:  can
# Workflow output:  be
# Workflow output:  created
# Workflow output:  confidently
# Workflow output: .
# Workflow output:  Detailed
# Workflow output:  documentation
# Workflow output:  and
# Workflow output:  templates
# Workflow output:  can
# Workflow output:  be
# Workflow output:  explored
# Workflow output:  in
# Workflow output:  the
# Workflow output:  [
# Workflow output: Microsoft
# Workflow output:  Agent
# Workflow output:  Framework
# Workflow output:  documentation
# Workflow output:  repository
# Workflow output: ](
# Workflow output: https
# Workflow output: ://
# Workflow output: github
# Workflow output: .com
# Workflow output: /m
# Workflow output: icrosoft
# Workflow output: /
# Workflow output: agent
# Workflow output: -framework
# Workflow output: /tree
# Workflow output: /main
# Workflow output: /docs
# Workflow output: /docs
# Workflow output: -
# Workflow output: templates
# Workflow output: ).\
# Workflow output: n
# Workflow output: \n
# Workflow output: \n
# Workflow output: ---
# Workflow output: \
# Workflow output: n
# Workflow output: \n
# Workflow output: This
# Workflow output:  tutorial
# Workflow output:  introduces
# Workflow output:  the
# Workflow output:  foundational
# Workflow output:  concepts
# Workflow output:  and
# Workflow output:  ecosystem
# Workflow output:  tools
# Workflow output:  for
# Workflow output:  understanding
# Workflow output:  and
# Workflow output:  deploying
# Workflow output:  AI
# Workflow output:  Agents
# Workflow output:  using
# Workflow output:  Microsoft
# Workflow output:  technologies
# Workflow output: .
# Workflow output:  By
# Workflow output:  leveraging
# Workflow output:  these
# Workflow output:  resources
# Workflow output: ,
# Workflow output:  developers
# Workflow output:  can
# Workflow output:  rapidly
# Workflow output:  accelerate
# Workflow output:  the
# Workflow output:  design
# Workflow output:  and
# Workflow output:  scaling
# Workflow output:  of
# Workflow output:  intelligent
# Workflow output:  agents
# Workflow output:  that
# Workflow output:  drive
# Workflow output:  business
# Workflow output:  innovation
# Workflow output:  and
# Workflow output:  operational
# Workflow output:  excellence
# Workflow output: .\
# Workflow output: n
# Workflow output: "
#
# Workflow output: }
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output: [AgentExecutorResponse(executor_id='evangelist_agent', agent_response=<agent_framework._types.AgentResponse object at 0x121edc770>, full_conversation=[<agent_framework._types.ChatMessage object at 0x1226f8230>, <agent_framework._types.ChatMessage object at 0x122ee3230>])]
# Workflow output: None
# Workflow output: AgentExecutorResponse(executor_id='evangelist_agent', agent_response=<agent_framework._types.AgentResponse object at 0x12426d790>, full_conversation=[<agent_framework._types.ChatMessage object at 0x123084230>, <agent_framework._types.ChatMessage object at 0x12426d970>])
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output: {
#
# Workflow output:
# Workflow output:  "
# Workflow output: review
# Workflow output: _result
# Workflow output: ":
# Workflow output:  "
# Workflow output: Yes
# Workflow output: ",
#
# Workflow output:
# Workflow output:  "
# Workflow output: reason
# Workflow output: ":
# Workflow output:  "
# Workflow output: The
# Workflow output:  content
# Workflow output:  is
# Workflow output:  good
# Workflow output: ",
#
# Workflow output:
# Workflow output:  "
# Workflow output: draft
# Workflow output: _content
# Workflow output: ":
# Workflow output:  "#
# Workflow output:  Introducing
# Workflow output:  AI
# Workflow output:  Agents
# Workflow output: :
# Workflow output:  Empower
# Workflow output: ing
# Workflow output:  Intelligent
# Workflow output:  Automation
# Workflow output: \n
# Workflow output: \n
# Workflow output: ##
# Workflow output:  What's
# Workflow output:  an
# Workflow output:  AI
# Workflow output:  Agent
# Workflow output: ?\
# Workflow output: n
# Workflow output: \n
# Workflow output: An
# Workflow output:  AI
# Workflow output:  Agent
# Workflow output:  is
# Workflow output:  a
# Workflow output:  software
# Workflow output:  entity
# Workflow output:  designed
# Workflow output:  to
# Workflow output:  autonom
# Workflow output: ously
# Workflow output:  perform
# Workflow output:  tasks
# Workflow output:  or
# Workflow output:  services
# Workflow output:  on
# Workflow output:  behalf
# Workflow output:  of
# Workflow output:  a
# Workflow output:  user
# Workflow output:  or
# Workflow output:  system
# Workflow output:  by
# Workflow output:  leveraging
# Workflow output:  artificial
# Workflow output:  intelligence
# Workflow output:  technologies
# Workflow output: .
# Workflow output:  These
# Workflow output:  agents
# Workflow output:  continuously
# Workflow output:  perceive
# Workflow output:  their
# Workflow output:  environment
# Workflow output: ,
# Workflow output:  make
# Workflow output:  decisions
# Workflow output:  based
# Workflow output:  on
# Workflow output:  the
# Workflow output:  information
# Workflow output:  available
# Workflow output: ,
# Workflow output:  and
# Workflow output:  act
# Workflow output:  towards
# Workflow output:  achieving
# Workflow output:  specific
# Workflow output:  goals
# Workflow output:  without
# Workflow output:  constant
# Workflow output:  human
# Workflow output:  intervention
# Workflow output: .
# Workflow output:  AI
# Workflow output:  Agents
# Workflow output:  can
# Workflow output:  range
# Workflow output:  from
# Workflow output:  simple
# Workflow output:  rule
# Workflow output: -based
# Workflow output:  systems
# Workflow output:  to
# Workflow output:  highly
# Workflow output:  complex
# Workflow output:  entities
# Workflow output:  that
# Workflow output:  use
# Workflow output:  machine
# Workflow output:  learning
# Workflow output: ,
# Workflow output:  natural
# Workflow output:  language
# Workflow output:  processing
# Workflow output: ,
# Workflow output:  and
# Workflow output:  reasoning
# Workflow output:  to
# Workflow output:  handle
# Workflow output:  dynamic
# Workflow output:  and
# Workflow output:  uncertain
# Workflow output:  environments
# Workflow output: .
# Workflow output:  They
# Workflow output:  effectively
# Workflow output:  streamline
# Workflow output:  workflows
# Workflow output: ,
# Workflow output:  enhance
# Workflow output:  decision
# Workflow output: -making
# Workflow output: ,
# Workflow output:  and
# Workflow output:  enable
# Workflow output:  scalable
# Workflow output:  automation
# Workflow output:  in
# Workflow output:  various
# Workflow output:  domains
# Workflow output: .\
# Workflow output: n
# Workflow output: \n
# Workflow output: The
# Workflow output:  fundamental
# Workflow output:  concept
# Workflow output:  of
# Workflow output:  AI
# Workflow output:  Agents
# Workflow output:  revolves
# Workflow output:  around
# Workflow output:  their
# Workflow output:  capability
# Workflow output:  to
# Workflow output:  understand
# Workflow output:  commands
# Workflow output: ,
# Workflow output:  learn
# Workflow output:  from
# Workflow output:  data
# Workflow output:  or
# Workflow output:  interactions
# Workflow output: ,
# Workflow output:  adapt
# Workflow output:  to
# Workflow output:  new
# Workflow output:  circumstances
# Workflow output: ,
# Workflow output:  and
# Workflow output:  proactively
# Workflow output:  execute
# Workflow output:  tasks
# Workflow output: .
# Workflow output:  This
# Workflow output:  autonomy
# Workflow output:  reduces
# Workflow output:  the
# Workflow output:  burden
# Workflow output:  on
# Workflow output:  human
# Workflow output:  operators
# Workflow output:  and
# Workflow output:  fosters
# Workflow output:  efficiency
# Workflow output:  by
# Workflow output:  allowing
# Workflow output:  intelligent
# Workflow output:  systems
# Workflow output:  to
# Workflow output:  manage
# Workflow output:  routine
# Workflow output: ,
# Workflow output:  repetitive
# Workflow output: ,
# Workflow output:  or
# Workflow output:  complex
# Workflow output:  activities
# Workflow output: .
# Workflow output:  You
# Workflow output:  can
# Workflow output:  explore
# Workflow output:  more
# Workflow output:  about
# Workflow output:  the
# Workflow output:  basics
# Workflow output:  and
# Workflow output:  how
# Workflow output:  AI
# Workflow output:  Agents
# Workflow output:  function
# Workflow output:  in
# Workflow output:  different
# Workflow output:  contexts
# Workflow output:  on
# Workflow output:  the
# Workflow output:  [
# Workflow output: AI
# Workflow output:  Agents
# Workflow output:  for
# Workflow output:  Beginners
# Workflow output:  repository
# Workflow output: ](
# Workflow output: https
# Workflow output: ://
# Workflow output: github
# Workflow output: .com
# Workflow output: /m
# Workflow output: icrosoft
# Workflow output: /
# Workflow output: ai
# Workflow output: -ag
# Workflow output: ents
# Workflow output: -for
# Workflow output: -b
# Workflow output: eg
# Workflow output: inners
# Workflow output: /tree
# Workflow output: /main
# Workflow output: /
# Workflow output: 01
# Workflow output: -int
# Workflow output: ro
# Workflow output: -to
# Workflow output: -ai
# Workflow output: -ag
# Workflow output: ents
# Workflow output: ).\
# Workflow output: n
# Workflow output: \n
# Workflow output: \n
# Workflow output: ##
# Workflow output:  Introducing
# Workflow output:  Azure
# Workflow output:  AI
# Workflow output:  Found
# Workflow output: ry
# Workflow output:  Agent
# Workflow output:  Service
# Workflow output: \n
# Workflow output: \n
# Workflow output: Azure
# Workflow output:  AI
# Workflow output:  Found
# Workflow output: ry
# Workflow output:  Agent
# Workflow output:  Service
# Workflow output:  is
# Workflow output:  a
# Workflow output:  breakthrough
# Workflow output:  cloud
# Workflow output: -based
# Workflow output:  platform
# Workflow output:  from
# Workflow output:  Microsoft
# Workflow output:  designed
# Workflow output:  to
# Workflow output:  build
# Workflow output: ,
# Workflow output:  deploy
# Workflow output: ,
# Workflow output:  and
# Workflow output:  manage
# Workflow output:  sophisticated
# Workflow output:  AI
# Workflow output:  Agents
# Workflow output:  at
# Workflow output:  scale
# Workflow output: .
# Workflow output:  This
# Workflow output:  service
# Workflow output:  empowers
# Workflow output:  developers
# Workflow output:  and
# Workflow output:  organizations
# Workflow output:  to
# Workflow output:  create
# Workflow output:  intelligent
# Workflow output:  agents
# Workflow output:  that
# Workflow output:  integrate
# Workflow output:  seamlessly
# Workflow output:  with
# Workflow output:  existing
# Workflow output:  enterprise
# Workflow output:  systems
# Workflow output:  while
# Workflow output:  benefiting
# Workflow output:  from
# Workflow output:  Azure
# Workflow output: 's
# Workflow output:  robust
# Workflow output:  infrastructure
# Workflow output: ,
# Workflow output:  security
# Workflow output: ,
# Workflow output:  and
# Workflow output:  AI
# Workflow output:  capabilities
# Workflow output: .\
# Workflow output: n
# Workflow output: \n
# Workflow output: The
# Workflow output:  Found
# Workflow output: ry
# Workflow output:  Agent
# Workflow output:  Service
# Workflow output:  simplifies
# Workflow output:  the
# Workflow output:  lifecycle
# Workflow output:  management
# Workflow output:  of
# Workflow output:  AI
# Workflow output:  Agents
# Workflow output:  through
# Workflow output:  features
# Workflow output:  like
# Workflow output:  version
# Workflow output:  control
# Workflow output: ,
# Workflow output:  environment
# Workflow output:  consistency
# Workflow output: ,
# Workflow output:  and
# Workflow output:  monitoring
# Workflow output: ,
# Workflow output:  all
# Workflow output:  hosted
# Workflow output:  on
# Workflow output:  Azure
# Workflow output: .
# Workflow output:  It
# Workflow output:  supports
# Workflow output:  multi
# Workflow output: -modal
# Workflow output:  interactions
# Workflow output: ,
# Workflow output:  enabling
# Workflow output:  agents
# Workflow output:  to
# Workflow output:  process
# Workflow output:  natural
# Workflow output:  language
# Workflow output: ,
# Workflow output:  handle
# Workflow output:  complex
# Workflow output:  workflows
# Workflow output: ,
# Workflow output:  and
# Workflow output:  make
# Workflow output:  real
# Workflow output: -time
# Workflow output:  decisions
# Workflow output: .
# Workflow output:  With
# Workflow output:  this
# Workflow output:  service
# Workflow output: ,
# Workflow output:  businesses
# Workflow output:  can
# Workflow output:  accelerate
# Workflow output:  the
# Workflow output:  deployment
# Workflow output:  of
# Workflow output:  AI
# Workflow output: -driven
# Workflow output:  solutions
# Workflow output:  that
# Workflow output:  optimize
# Workflow output:  customer
# Workflow output:  engagement
# Workflow output: ,
# Workflow output:  automate
# Workflow output:  operations
# Workflow output: ,
# Workflow output:  and
# Workflow output:  enhance
# Workflow output:  analytics
# Workflow output: .\
# Workflow output: n
# Workflow output: \n
# Workflow output: Additionally
# Workflow output: ,
# Workflow output:  Azure
# Workflow output:  AI
# Workflow output:  Found
# Workflow output: ry
# Workflow output:  provides
# Workflow output:  extens
# Workflow output: ibility
# Workflow output:  and
# Workflow output:  integration
# Workflow output:  options
# Workflow output: ,
# Workflow output:  making
# Workflow output:  it
# Workflow output:  suitable
# Workflow output:  for
# Workflow output:  diverse
# Workflow output:  industries
# Workflow output:  ranging
# Workflow output:  from
# Workflow output:  finance
# Workflow output:  and
# Workflow output:  healthcare
# Workflow output:  to
# Workflow output:  retail
# Workflow output:  and
# Workflow output:  manufacturing
# Workflow output: .
# Workflow output:  For
# Workflow output:  an
# Workflow output:  in
# Workflow output: -depth
# Workflow output:  look
# Workflow output:  at
# Workflow output:  the
# Workflow output:  service
# Workflow output: ’s
# Workflow output:  capabilities
# Workflow output: ,
# Workflow output:  architecture
# Workflow output: ,
# Workflow output:  and
# Workflow output:  getting
# Workflow output:  started
# Workflow output:  guide
# Workflow output: ,
# Workflow output:  please
# Workflow output:  visit
# Workflow output:  the
# Workflow output:  official
# Workflow output:  [
# Workflow output: Azure
# Workflow output:  AI
# Workflow output:  Found
# Workflow output: ry
# Workflow output:  Agent
# Workflow output:  Service
# Workflow output:  overview
# Workflow output: ](
# Workflow output: https
# Workflow output: ://
# Workflow output: learn
# Workflow output: .microsoft
# Workflow output: .com
# Workflow output: /en
# Workflow output: -us
# Workflow output: /
# Workflow output: azure
# Workflow output: /
# Workflow output: ai
# Workflow output: -found
# Workflow output: ry
# Workflow output: /
# Workflow output: agents
# Workflow output: /
# Workflow output: overview
# Workflow output: ).\
# Workflow output: n
# Workflow output: \n
# Workflow output: \n
# Workflow output: ##
# Workflow output:  Microsoft
# Workflow output:  Agent
# Workflow output:  Framework
# Workflow output: \n
# Workflow output: \n
# Workflow output: The
# Workflow output:  Microsoft
# Workflow output:  Agent
# Workflow output:  Framework
# Workflow output:  is
# Workflow output:  an
# Workflow output:  open
# Workflow output: -source
# Workflow output:  initiative
# Workflow output:  that
# Workflow output:  provides
# Workflow output:  a
# Workflow output:  comprehensive
# Workflow output:  set
# Workflow output:  of
# Workflow output:  tools
# Workflow output: ,
# Workflow output:  SDK
# Workflow output: s
# Workflow output: ,
# Workflow output:  and
# Workflow output:  documentation
# Workflow output:  for
# Workflow output:  developing
# Workflow output:  AI
# Workflow output:  Agents
# Workflow output: .
# Workflow output:  It
# Workflow output:  stream
# Workflow output: lines
# Workflow output:  the
# Workflow output:  creation
# Workflow output:  of
# Workflow output:  intelligent
# Workflow output:  applications
# Workflow output:  by
# Workflow output:  offering
# Workflow output:  modular
# Workflow output:  components
# Workflow output: ,
# Workflow output:  reusable
# Workflow output:  templates
# Workflow output: ,
# Workflow output:  and
# Workflow output:  developer
# Workflow output: -friendly
# Workflow output:  interfaces
# Workflow output: .\
# Workflow output: n
# Workflow output: \n
# Workflow output: This
# Workflow output:  framework
# Workflow output:  supports
# Workflow output:  the
# Workflow output:  seamless
# Workflow output:  integration
# Workflow output:  of
# Workflow output:  AI
# Workflow output:  Agents
# Workflow output:  with
# Workflow output:  diverse
# Workflow output:  communication
# Workflow output:  channels
# Workflow output: ,
# Workflow output:  including
# Workflow output:  chat
# Workflow output: ,
# Workflow output:  voice
# Workflow output: ,
# Workflow output:  and
# Workflow output:  messaging
# Workflow output:  platforms
# Workflow output: ,
# Workflow output:  enabling
# Workflow output:  rich
# Workflow output:  and
# Workflow output:  interactive
# Workflow output:  user
# Workflow output:  experiences
# Workflow output: .
# Workflow output:  The
# Workflow output:  modular
# Workflow output:  design
# Workflow output:  promotes
# Workflow output:  scalability
# Workflow output:  and
# Workflow output:  adaptability
# Workflow output: ,
# Workflow output:  helping
# Workflow output:  developers
# Workflow output:  to
# Workflow output:  customize
# Workflow output:  agents
# Workflow output:  to
# Workflow output:  specific
# Workflow output:  business
# Workflow output:  needs
# Workflow output:  without
# Workflow output:  building
# Workflow output:  everything
# Workflow output:  from
# Workflow output:  scratch
# Workflow output: .\
# Workflow output: n
# Workflow output: \n
# Workflow output: Moreover
# Workflow output: ,
# Workflow output:  the
# Workflow output:  Microsoft
# Workflow output:  Agent
# Workflow output:  Framework
# Workflow output:  emphasizes
# Workflow output:  best
# Workflow output:  practices
# Workflow output:  for
# Workflow output:  security
# Workflow output: ,
# Workflow output:  compliance
# Workflow output: ,
# Workflow output:  and
# Workflow output:  performance
# Workflow output:  optimization
# Workflow output: ,
# Workflow output:  ensuring
# Workflow output:  that
# Workflow output:  enterprise
# Workflow output: -grade
# Workflow output:  AI
# Workflow output:  Agents
# Workflow output:  can
# Workflow output:  be
# Workflow output:  created
# Workflow output:  confidently
# Workflow output: .
# Workflow output:  Detailed
# Workflow output:  documentation
# Workflow output:  and
# Workflow output:  templates
# Workflow output:  can
# Workflow output:  be
# Workflow output:  explored
# Workflow output:  in
# Workflow output:  the
# Workflow output:  [
# Workflow output: Microsoft
# Workflow output:  Agent
# Workflow output:  Framework
# Workflow output:  documentation
# Workflow output:  repository
# Workflow output: ](
# Workflow output: https
# Workflow output: ://
# Workflow output: github
# Workflow output: .com
# Workflow output: /m
# Workflow output: icrosoft
# Workflow output: /
# Workflow output: agent
# Workflow output: -framework
# Workflow output: /tree
# Workflow output: /main
# Workflow output: /docs
# Workflow output: /docs
# Workflow output: -
# Workflow output: templates
# Workflow output: ).\
# Workflow output: n
# Workflow output: \n
# Workflow output: \n
# Workflow output: ---
# Workflow output: \
# Workflow output: n
# Workflow output: \n
# Workflow output: This
# Workflow output:  tutorial
# Workflow output:  introduces
# Workflow output:  the
# Workflow output:  foundational
# Workflow output:  concepts
# Workflow output:  and
# Workflow output:  ecosystem
# Workflow output:  tools
# Workflow output:  for
# Workflow output:  understanding
# Workflow output:  and
# Workflow output:  deploying
# Workflow output:  AI
# Workflow output:  Agents
# Workflow output:  using
# Workflow output:  Microsoft
# Workflow output:  technologies
# Workflow output: .
# Workflow output:  By
# Workflow output:  leveraging
# Workflow output:  these
# Workflow output:  resources
# Workflow output: ,
# Workflow output:  developers
# Workflow output:  can
# Workflow output:  rapidly
# Workflow output:  accelerate
# Workflow output:  the
# Workflow output:  design
# Workflow output:  and
# Workflow output:  scaling
# Workflow output:  of
# Workflow output:  intelligent
# Workflow output:  agents
# Workflow output:  that
# Workflow output:  drive
# Workflow output:  business
# Workflow output:  innovation
# Workflow output:  and
# Workflow output:  operational
# Workflow output:  excellence
# Workflow output: .\
# Workflow output: n
# Workflow output: "
#
# Workflow output: }
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output: [AgentExecutorResponse(executor_id='reviewer_agent', agent_response=<agent_framework._types.AgentResponse object at 0x12426d610>, full_conversation=[<agent_framework._types.ChatMessage object at 0x1226f8230>, <agent_framework._types.ChatMessage object at 0x122ee3230>, <agent_framework._types.ChatMessage object at 0x124a02f00>])]
# Workflow output: None
# Workflow output: None
# Raw response from reviewer agent: {
#   "review_result": "Yes",
#   "reason": "The content is good",
#   "draft_content": "# Introducing AI Agents: Empowering Intelligent Automation\n\n## What's an AI Agent?\n\nAn AI Agent is a software entity designed to autonomously perform tasks or services on behalf of a user or system by leveraging artificial intelligence technologies. These agents continuously perceive their environment, make decisions based on the information available, and act towards achieving specific goals without constant human intervention. AI Agents can range from simple rule-based systems to highly complex entities that use machine learning, natural language processing, and reasoning to handle dynamic and uncertain environments. They effectively streamline workflows, enhance decision-making, and enable scalable automation in various domains.\n\nThe fundamental concept of AI Agents revolves around their capability to understand commands, learn from data or interactions, adapt to new circumstances, and proactively execute tasks. This autonomy reduces the burden on human operators and fosters efficiency by allowing intelligent systems to manage routine, repetitive, or complex activities. You can explore more about the basics and how AI Agents function in different contexts on the [AI Agents for Beginners repository](https://github.com/microsoft/ai-agents-for-beginners/tree/main/01-intro-to-ai-agents).\n\n\n## Introducing Azure AI Foundry Agent Service\n\nAzure AI Foundry Agent Service is a breakthrough cloud-based platform from Microsoft designed to build, deploy, and manage sophisticated AI Agents at scale. This service empowers developers and organizations to create intelligent agents that integrate seamlessly with existing enterprise systems while benefiting from Azure's robust infrastructure, security, and AI capabilities.\n\nThe Foundry Agent Service simplifies the lifecycle management of AI Agents through features like version control, environment consistency, and monitoring, all hosted on Azure. It supports multi-modal interactions, enabling agents to process natural language, handle complex workflows, and make real-time decisions. With this service, businesses can accelerate the deployment of AI-driven solutions that optimize customer engagement, automate operations, and enhance analytics.\n\nAdditionally, Azure AI Foundry provides extensibility and integration options, making it suitable for diverse industries ranging from finance and healthcare to retail and manufacturing. For an in-depth look at the service’s capabilities, architecture, and getting started guide, please visit the official [Azure AI Foundry Agent Service overview](https://learn.microsoft.com/en-us/azure/ai-foundry/agents/overview).\n\n\n## Microsoft Agent Framework\n\nThe Microsoft Agent Framework is an open-source initiative that provides a comprehensive set of tools, SDKs, and documentation for developing AI Agents. It streamlines the creation of intelligent applications by offering modular components, reusable templates, and developer-friendly interfaces.\n\nThis framework supports the seamless integration of AI Agents with diverse communication channels, including chat, voice, and messaging platforms, enabling rich and interactive user experiences. The modular design promotes scalability and adaptability, helping developers to customize agents to specific business needs without building everything from scratch.\n\nMoreover, the Microsoft Agent Framework emphasizes best practices for security, compliance, and performance optimization, ensuring that enterprise-grade AI Agents can be created confidently. Detailed documentation and templates can be explored in the [Microsoft Agent Framework documentation repository](https://github.com/microsoft/agent-framework/tree/main/docs/docs-templates).\n\n\n---\n\nThis tutorial introduces the foundational concepts and ecosystem tools for understanding and deploying AI Agents using Microsoft technologies. By leveraging these resources, developers can rapidly accelerate the design and scaling of intell ...
# }
# Workflow output: AgentExecutorResponse(executor_id='reviewer_agent', agent_response=<agent_framework._types.AgentResponse object at 0x12314d610>, full_conversation=[<agent_framework._types.ChatMessage object at 0x12314df10>, <agent_framework._types.ChatMessage object at 0x12314e6c0>, <agent_framework._types.ChatMessage object at 0x12342dfa0>])
# Workflow output: [ReviewResult(review_result='Yes', reason='The content is good', draft_content="# Introducing AI Agents: Empowering Intelligent Automation\n\n## What's an AI Agent?\n\nAn AI Agent is a software entity designed to autonomously perform tasks or services on behalf of a user or system by leveraging artificial intelligence technologies. These agents continuously perceive their environment, make decisions based on the information available, and act towards achieving specific goals without constant human intervention. AI Agents can range from simple rule-based systems to highly complex entities that use machine learning, natural language processing, and reasoning to handle dynamic and uncertain environments. They effectively streamline workflows, enhance decision-making, and enable scalable automation in various domains.\n\nThe fundamental concept of AI Agents revolves around their capability to understand commands, learn from data or interactions, adapt to new circumstances, and proactively execute tasks. This autonomy reduces the burden on human operators and fosters efficiency by allowing intelligent systems to manage routine, repetitive, or complex activities. You can explore more about the basics and how AI Agents function in different contexts on the [AI Agents for Beginners repository](https://github.com/microsoft/ai-agents-for-beginners/tree/main/01-intro-to-ai-agents).\n\n\n## Introducing Azure AI Foundry Agent Service\n\nAzure AI Foundry Agent Service is a breakthrough cloud-based platform from Microsoft designed to build, deploy, and manage sophisticated AI Agents at scale. This service empowers developers and organizations to create intelligent agents that integrate seamlessly with existing enterprise systems while benefiting from Azure's robust infrastructure, security, and AI capabilities.\n\nThe Foundry Agent Service simplifies the lifecycle management of AI Agents through features like version control, environment consistency, and monitoring, all hosted on Azure. It supports multi-modal interactions, enabling agents to process natural language, handle complex workflows, and make real-time decisions. With this service, businesses can accelerate the deployment of AI-driven solutions that optimize customer engagement, automate operations, and enhance analytics.\n\nAdditionally, Azure AI Foundry provides extensibility and integration options, making it suitable for diverse industries ranging from finance and healthcare to retail and manufacturing. For an in-depth look at the service’s capabilities, architecture, and getting started guide, please visit the official [Azure AI Foundry Agent Service overview](https://learn.microsoft.com/en-us/azure/ai-foundry/agents/overview).\n\n\n## Microsoft Agent Framework\n\nThe Microsoft Agent Framework is an open-source initiative that provides a comprehensive set of tools, SDKs, and documentation for developing AI Agents. It streamlines the creation of intelligent applications by offering modular components, reusable templates, and developer-friendly interfaces.\n\nThis framework supports the seamless integration of AI Agents with diverse communication channels, including chat, voice, and messaging platforms, enabling rich and interactive user experiences. The modular design promotes scalability and adaptability, helping developers to customize agents to specific business needs without building everything from scratch.\n\nMoreover, the Microsoft Agent Framework emphasizes best practices for security, compliance, and performance optimization, ensuring that enterprise-grade AI Agents can be created confidently. Detailed documentation and templates can be explored in the [Microsoft Agent Framework documentation repository](https://github.com/microsoft/agent-framework/tree/main/docs/docs-templates).\n\n\n---\n\nThis tutorial introduces the foundational concepts and ecosystem tools for understanding and deploying AI Agents using Microsoft technologies. By leveraging these  ...
# Workflow output: None
# Workflow output: None
# ...
# Workflow output: [AgentExecutorRequest(messages=[<agent_framework._types.ChatMessage object at 0x1234f0440>], should_respond=True)]
# Workflow output: None
# Workflow output: None
# Workflow output: AgentExecutorRequest(messages=[<agent_framework._types.ChatMessage object at 0x123774dd0>], should_respond=True)
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output: The
# Workflow output:  tutorial
# Workflow output:  draft
# Workflow output:  has
# Workflow output:  been
# Workflow output:  saved
# Workflow output:  as
# Workflow output:  a
# Workflow output:  Markdown
# Workflow output:  file
# Workflow output: .
#
#
# Workflow output: [
# Workflow output: Download
# Workflow output:  the
# Workflow output:  tutorial
# Workflow output:  draft
# Workflow output: ](
# Workflow output: sandbox
# Workflow output: :/
# Workflow output: mnt
# Workflow output: /data
# Workflow output: /
# Workflow output: 202
# Workflow output: 601
# Workflow output: 220
# Workflow output: 238
# Workflow output: 09
# Workflow output: .md
# Workflow output: )
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output: [AgentExecutorResponse(executor_id='publisher_agent', agent_response=<agent_framework._types.AgentResponse object at 0x123cbdca0>, full_conversation=[<agent_framework._types.ChatMessage object at 0x1234f0440>, <agent_framework._types.ChatMessage object at 0x123774080>])]
# Workflow output: None
# Workflow output: None
# Workflow output: None
# Workflow output: None
# done
