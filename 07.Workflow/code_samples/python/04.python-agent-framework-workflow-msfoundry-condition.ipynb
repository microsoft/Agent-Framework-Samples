# %% [markdown]
# # 🔀 Conditional Agent Workflows with Azure AI Foundry (Python)
#
# ## 📋 Advanced Decision-Based Workflow Tutorial
#
# This notebook demonstrates **conditional workflow patterns** using Azure AI Foundry and the Microsoft Agent Framework. You'll learn how to build intelligent, decision-driven workflows that dynamically route processing based on content analysis, business rules, and AI-powered decision making.
#
# ## 🎯 Learning Objectives
#
# ### 🧠 **Intelligent Decision Making**
# - **Conditional Logic**: Implement dynamic branching based on AI analysis and business rules
# - **Content-Aware Routing**: Route workflow paths based on content analysis and classification
# - **Adaptive Processing**: Adjust workflow behavior based on real-time conditions and data
# - **Azure AI Integration**: Leverage Azure AI Foundry's advanced capabilities for decision making
#
# ### 🔀 **Advanced Workflow Patterns**
# - **Decision Trees**: Build complex decision structures with multiple branching points
# - **Rule-Based Processing**: Implement business logic and compliance requirements
# - **Dynamic Workflow Modification**: Adapt workflows based on runtime conditions
# - **Context-Aware Operations**: Make decisions based on accumulated workflow context
#
# ### 🏢 **Enterprise Conditional Applications**
# - **Document Classification**: Route documents to appropriate processing workflows
# - **Customer Service Triage**: Automatically route inquiries to specialized handling workflows
# - **Compliance Processing**: Apply different validation rules based on content type and regulations
# - **Quality Assurance**: Route content through different review processes based on quality metrics
#
# ## ⚙️ Prerequisites & Setup
#
# ### 📦 **Installation & Dependencies**
#
# This workflow requires specific installation steps for Azure AI Foundry integration:
#
# ```bash
#
# pip install agent-framework-azure-ai -U
# ```
#
# ### 🔑 **Azure AI Foundry Configuration**
#
# **Required Azure Resources:**
# - Azure AI Foundry workspace with appropriate models deployed
# - Azure subscription with necessary permissions
# - Azure CLI authentication configured
#
#
# **Authentication Setup:**
# ```bash
# # Azure CLI authentication
# az login
# az account set --subscription "your-subscription-id"
# azd auth login
# ```
#
# ### 🏗️ **Conditional Workflow Architecture**
#
# ```mermaid
# graph TD
#     A[Input Document/Request] --> B[Initial Analysis Agent]
#     B --> C{Decision Point}
#     C -->|Condition 1| D[Workflow Path A]
#     C -->|Condition 2| E[Workflow Path B]
#     C -->|Condition 3| F[Workflow Path C]
#     D --> G[Specialized Processing A]
#     E --> H[Specialized Processing B]
#     F --> I[Specialized Processing C]
#     G --> J[Result Integration]
#     H --> J
#     I --> J
#     J --> K[Final Output]
# ```
#
# **Key Components:**
# - **Analysis Agents**: AI agents that evaluate content and make routing decisions
# - **Decision Points**: Conditional logic that determines workflow paths
# - **Specialized Processors**: Different agents optimized for specific content types or scenarios
# - **Integration Layer**: Combines results from different workflow paths
#
# ## 🎨 **Conditional Workflow Design Patterns**
#
# ### 📋 **Document Processing Triage**
# ```
# Document Input → Content Analysis → Classification → Specialized Processing Workflow
# ```
#
# ### 🎯 **Customer Service Routing**
# ```
# Customer Inquiry → Intent Analysis → Urgency Assessment → Route to Specialist Team
# ```
#
# ### 🔍 **Quality Assurance Workflow**
# ```
# Content Input → Quality Metrics → Risk Assessment → Appropriate Review Process
# ```
#
# ### 📊 **Business Intelligence Pipeline**
# ```
# Data Input → Source Analysis → Processing Rules → Specialized Analytics Workflow
# ```
#
# ## 🏢 **Enterprise Benefits**
#
# ### 🎯 **Intelligent Automation**
# - **Smart Routing**: Automatically direct work to the most appropriate processing path
# - **Adaptive Behavior**: Workflows that learn and adapt based on patterns and outcomes
# - **Business Rule Integration**: Incorporate complex business logic and compliance requirements
# - **Context-Aware Processing**: Make decisions based on full workflow context and history
#
# ### 📈 **Operational Efficiency**
# - **Reduced Manual Intervention**: Automated decision making reduces need for human routing
# - **Specialized Processing**: Each workflow path optimized for specific scenarios
# - **Resource Optimization**: Efficient allocation of processing resources based on content type
# - **Faster Time-to-Resolution**: Direct routing to appropriate specialists and processes
#
# ### 🛡️ **Governance & Control**
# - **Audit Trails**: Complete logging of decision points and routing rationale
# - **Compliance Enforcement**: Automatic application of regulatory and policy requirements
# - **Risk Management**: Route high-risk content through enhanced security and review processes
# - **Quality Assurance**: Ensure appropriate level of review based on content characteristics
#
# ### 📊 **Analytics & Optimization**
# - **Decision Analytics**: Track effectiveness of routing decisions and workflow paths
# - **Performance Metrics**: Measure efficiency of different workflow branches
# - **Continuous Improvement**: Identify optimization opportunities in conditional logic
# - **Business Intelligence**: Gain insights into content patterns and processing requirements
#
# Let's build intelligent, decision-driven AI workflows! 🚀

# %%
####### Linux / MacOS Setup Instructions #######

####### Linux Instructions #######
# ! sudo apt update 
# ! sudo apt install graphviz -y

####### macOS Instructions #######
# ! brew install graphviz

# %%
# ! pip install -r ../../../Installation/requirements.txt -U

# %% [markdown]
# requirements.txt & constraints.txt - in ./Installation
#
# please copy .env.examples as .env

# %% [markdown]
# **Note** choose gpt-4.1-mini

# %%
import os

from dataclasses import dataclass
from typing_extensions import Literal
from pydantic import BaseModel

# %%
from azure.identity.aio import AzureCliCredential
from dotenv import load_dotenv

from agent_framework import HostedCodeInterpreterTool
from azure.ai.agents.models import CodeInterpreterTool
from agent_framework.azure import AzureAIProjectAgentProvider
from agent_framework import (
    AgentExecutor,
    AgentExecutorRequest,
    AgentExecutorResponse,
    ChatMessage,
    Role,
    WorkflowBuilder,
    WorkflowContext,
    WorkflowEvent,
    executor,
    WorkflowViz
)

# %%
load_dotenv()
# Out:
# True

# %%
EvangelistInstructions = """
You are a technology evangelist create a first draft for a technical tutorials.
1. Each knowledge point in the outline must include a link. Follow the link to access the content related to the knowledge point in the outline. Expand on that content.
2. Each knowledge point must be explained in detail.
3. Rewrite the content according to the entry requirements, including the title, outline, and corresponding content. It is not necessary to follow the outline in full order.
4. The content must be more than 200 words.
4. Output draft as Markdown format. set 'draft_content' to the draft content.
5. return result as JSON with fields 'draft_content' (string).
"""

ContentReviewerInstructions = """
You are a content reviewer for a publishing company. You need to check whether the tutorial's draft content meets the following requirements:

1. The draft content less than 200 words, set 'review_result' to 'No' and 'reason' to 'Content is too short'. If the draft content is more than 200 words, set 'review_result' to 'Yes' and 'reason' to 'The content is good'.
2. set 'draft_content' to the original draft content.
3. return result as JSON with fields 'review_result' (one of Yes, No) and 'reason' (string) and 'draft_content' (string).

"""

PublisherInstructions = """
You are the content publisher ,run code to save the tutorial's draft content as a Markdown file. Saved file's name is marked with current date and time, such as yearmonthdayhourminsec. Note that if it is 1-9, you need to add 0, such as  20240101123045.md. 
"""

# %%
OUTLINE_Content ="""
# Introduce AI Agent


## What's AI Agent

https://github.com/microsoft/ai-agents-for-beginners/tree/main/01-intro-to-ai-agents


***Note*** Don's create any sample code 


## Introduce Azure AI Foundry Agent Service 

https://learn.microsoft.com/en-us/azure/ai-foundry/agents/overview


***Note*** Don's create any sample code 


## Microsoft Agent Framework 

https://github.com/microsoft/agent-framework/tree/main/docs/docs-templates


***Note*** Don's create any sample code 
"""

# %%
# Note: Tools are now configured inline when creating agents

# %%
class EvangelistAgent(BaseModel):
    draft_content: str

class ReviewAgent(BaseModel):
    review_result: Literal["Yes", "No"]
    reason: str
    draft_content: str

class PublisherAgent(BaseModel):
    file_path: str

@dataclass
class ReviewResult:
    review_result: str
    reason: str
    draft_content: str

@executor(id="to_reviewer_result")
async def to_reviewer_result(response: AgentExecutorResponse, ctx: WorkflowContext[ReviewResult]) -> None:
    # Get the last message text from the response
    response_text = response.agent_response.text.strip()
    print(f"Raw response from reviewer agent: {response_text}")

    parsed = ReviewAgent.model_validate_json(response_text)
    await ctx.send_message(
        ReviewResult(
            review_result=parsed.review_result,
            reason=parsed.reason,
            draft_content=parsed.draft_content,
        )
    )


def select_targets(review: ReviewResult, target_ids: list[str]) -> list[str]:
        # Order: [handle_review, submit_to_email_assistant, summarize_email, handle_uncertain]
        handle_review_id, save_draft_id = target_ids
        if review.review_result == "Yes":
            return [save_draft_id]
        else:
            return [handle_review_id]
        


@executor(id="handle_review")
async def handle_review(review: ReviewResult, ctx: WorkflowContext[str]) -> None:
    if review.review_result == "No":
        await ctx.yield_output(f"Review failed: {review.reason}, please revise the draft.")
    else:
        await ctx.send_message(
            AgentExecutorRequest(messages=[ChatMessage(Role.USER, text=review.draft_content)], should_respond=True)
        )


@executor(id="save_draft")
async def save_draft(review: ReviewResult, ctx: WorkflowContext[AgentExecutorRequest]) -> None:
    # Only called for long NotSpam emails by selection_func
    await ctx.send_message(
        AgentExecutorRequest(messages=[ChatMessage(Role.USER, text=review.draft_content)], should_respond=True)
    )

# %%
from IPython.display import SVG, display, HTML

# %%
class DatabaseEvent(WorkflowEvent): ...

# %%
async with (
        AzureCliCredential() as credential,
        AzureAIProjectAgentProvider(project_endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"], credential=credential) as client,
    ):  
        try:
                evangelist_agent_obj = await client.create_agent(
                    name="evangelist-agent",
                    instructions=EvangelistInstructions,
                    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
                    tools=[
                        {
                            "type": "bing_grounding",
                            "bing_grounding": {
                                "search_configurations": [
                                    {
                                        "project_connection_id": os.environ["BING_CONNECTION_ID"],
                                    }
                                ]
                            },
                        }
                    ],
                    # response_format=EvangelistAgent
                )
                evangelist_agent = AgentExecutor(evangelist_agent_obj, id="evangelist_agent")
                
                reviewer_agent_obj = await client.create_agent(
                    name="reviewer-agent",
                    instructions=ContentReviewerInstructions,
                    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
                    # response_format=ReviewAgent
                )
                reviewer_agent = AgentExecutor(reviewer_agent_obj, id="reviewer_agent")
                
                publisher_agent_obj = await client.create_agent(
                    name="publisher-agent",
                    instructions=PublisherInstructions,
                    model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
                    tools=HostedCodeInterpreterTool()
                    # response_format=PublisherAgent
                )
                publisher_agent = AgentExecutor(publisher_agent_obj, id="publisher_agent")

                workflow = (
                    WorkflowBuilder()
                        .set_start_executor(evangelist_agent)
                        .add_edge(evangelist_agent, reviewer_agent)
                        .add_edge(reviewer_agent, to_reviewer_result)
                        .add_multi_selection_edge_group(
                            to_reviewer_result,
                            [handle_review, save_draft],
                            selection_func=select_targets,
                        )
                        .add_edge(save_draft, publisher_agent)
                        .build()
                )

                # workflow = SequentialBuilder().participants([evangelist_chat_agent, reviewer_chat_agent, publisher_chat_agent]).build()
                print("Generating workflow visualization...")
                viz = WorkflowViz(workflow)
                # Print out the mermaid string.
                print("Mermaid string: \n=======")
                print(viz.to_mermaid())
                print("=======")
                # Print out the DiGraph string.
                print("DiGraph string: \n=======")
                print(viz.to_digraph())
                print("=======")
                svg_file = viz.export(format="svg")
                print(f"SVG file saved to: {svg_file}")

                if svg_file and os.path.exists(svg_file):
                    try:
                        # Preferred: direct SVG rendering
                        display(SVG(filename=svg_file))
                    except Exception as e:
                        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
                        try:
                            with open(svg_file, "r", encoding="utf-8") as f:
                                svg_text = f.read()
                            display(HTML(svg_text))
                        except Exception as inner:
                            print(f"❌ Fallback HTML render also failed: {inner}")
                else:
                    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")

                
                task = """
                    You are a evangelist , need to write a  draft based on the following outline and the content provided in the link corresponding to the outline. After draft create , the reviewer check it , if it meets the requirements, it will be submitted to the publisher and save it as a Markdown file, otherwise need to rewrite draft until it meets the requirements.
                        The provided outline content and related links is as follows:

                    """ + OUTLINE_Content

                
                async for event in workflow.run_stream(task):
                    if isinstance(event, DatabaseEvent):
                        print(f"{event}")
                    if isinstance(event, WorkflowEvent):
                        print(f"Workflow output: {event.data}")



        finally:
            print("done")
# Out:
# Generating workflow visualization...
# Mermaid string:
# =======
# flowchart TD
#   evangelist_agent["evangelist_agent (Start)"];
#   reviewer_agent["reviewer_agent"];
#   to_reviewer_result["to_reviewer_result"];
#   handle_review["handle_review"];
#   save_draft["save_draft"];
#   publisher_agent["publisher_agent"];
#   evangelist_agent --> reviewer_agent;
#   reviewer_agent --> to_reviewer_result;
#   to_reviewer_result --> handle_review;
#   to_reviewer_result --> save_draft;
#   save_draft --> publisher_agent;
# =======
# DiGraph string:
# =======
# digraph Workflow {
#   rankdir=TD;
#   node [shape=box, style=filled, fillcolor=lightblue];
#   edge [color=black, arrowhead=vee];
#
#   "evangelist_agent" [fillcolor=lightgreen, label="evangelist_agent\n(Start)"];
#   "reviewer_agent" [label="reviewer_agent"];
#   "to_reviewer_result" [label="to_reviewer_result"];
#   "handle_review" [label="handle_review"];
#   "save_draft" [label="save_draft"];
#   "publisher_agent" [label="publisher_agent"];
#   "evangelist_agent" -> "reviewer_agent";
#   "reviewer_agent" -> "to_reviewer_result";
#   "to_reviewer_result" -> "handle_review";
#   "to_reviewer_result" -> "save_draft";
#   "save_draft" -> "publisher_agent";
# }
# =======
# SVG file saved to: /var/folders/66/m82q566n4c130x_vdtybj5b40000gn/T/tmp5j7fsmls.svg
# Workflow output: None
# Workflow output: None
# Workflow output:
#                     You are a evangelist , need to write a  draft based on the following outline and the content provided in the link corresponding to the outline. After draft create , the reviewer check it , if it meets the requirements, it will be submitted to the publisher and save it as a Markdown file, otherwise need to rewrite draft until it meets the requirements.
#                         The provided outline content and related links is as follows:
#
#
# # Introduce AI Agent
#
#
# ## What's AI Agent
#
# https://github.com/microsoft/ai-agents-for-beginners/tree/main/01-intro-to-ai-agents
#
#
# ***Note*** Don's create any sample code
#
#
# ## Introduce Azure AI Foundry Agent Service
#
# https://learn.microsoft.com/en-us/azure/ai-foundry/agents/overview
#
#
# ***Note*** Don's create any sample code
#
#
# ## Microsoft Agent Framework
#
# https://github.com/microsoft/agent-framework/tree/main/docs/docs-templates
#
#
# ***Note*** Don's create any sample code
#
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output: {
#
# Workflow output:
# Workflow output:  "
# Workflow output: draft
# Workflow output: _content
# Workflow output: ":
# Workflow output:  "#
# Workflow output:  Introducing
# Workflow output:  AI
# Workflow output:  Agents
# Workflow output: :
# Workflow output:  Empower
# Workflow output: ing
# Workflow output:  Intelligent
# Workflow output:  Automation
# Workflow output: \n
# Workflow output: \n
# Workflow output: ##
# Workflow output:  What
# Workflow output:  is
# Workflow output:  an
# Workflow output:  AI
# Workflow output:  Agent
# Workflow output: ?\
# Workflow output: n
# Workflow output: \n
# Workflow output: An
# Workflow output:  AI
# Workflow output:  Agent
# Workflow output:  is
# Workflow output:  a
# Workflow output:  sophisticated
# Workflow output:  software
# Workflow output:  entity
# Workflow output:  that
# Workflow output:  can
# Workflow output:  autonom
# Workflow output: ously
# Workflow output:  perform
# Workflow output:  tasks
# Workflow output:  by
# Workflow output:  making
# Workflow output:  decisions
# Workflow output: ,
# Workflow output:  invoking
# Workflow output:  tools
# Workflow output: ,
# Workflow output:  and
# Workflow output:  participating
# Workflow output:  in
# Workflow output:  workflows
# Workflow output: .
# Workflow output:  They
# Workflow output:  operate
# Workflow output:  either
# Workflow output:  independently
# Workflow output:  or
# Workflow output:  collaboratively
# Workflow output:  with
# Workflow output:  other
# Workflow output:  agents
# Workflow output:  or
# Workflow output:  humans
# Workflow output:  to
# Workflow output:  accomplish
# Workflow output:  specific
# Workflow output:  goals
# Workflow output: .
# Workflow output:  This
# Workflow output:  concept
# Workflow output:  forms
# Workflow output:  the
# Workflow output:  foundation
# Workflow output:  of
# Workflow output:  many
# Workflow output:  modern
# Workflow output:  intelligent
# Workflow output:  systems
# Workflow output: ,
# Workflow output:  where
# Workflow output:  agents
# Workflow output:  not
# Workflow output:  only
# Workflow output:  follow
# Workflow output:  predefined
# Workflow output:  instructions
# Workflow output:  but
# Workflow output:  also
# Workflow output:  learn
# Workflow output:  and
# Workflow output:  adapt
# Workflow output:  based
# Workflow output:  on
# Workflow output:  context
# Workflow output:  and
# Workflow output:  data
# Workflow output: .
# Workflow output:  Microsoft's
# Workflow output:  AI
# Workflow output:  Agents
# Workflow output:  for
# Workflow output:  Beginners
# Workflow output:  repository
# Workflow output:  offers
# Workflow output:  a
# Workflow output:  comprehensive
# Workflow output:  introduction
# Workflow output:  to
# Workflow output:  these
# Workflow output:  concepts
# Workflow output: ,
# Workflow output:  explaining
# Workflow output:  that
# Workflow output:  AI
# Workflow output:  agents
# Workflow output:  are
# Workflow output:  designed
# Workflow output:  to
# Workflow output:  automate
# Workflow output:  repetitive
# Workflow output:  and
# Workflow output:  predictable
# Workflow output:  tasks
# Workflow output: ,
# Workflow output:  freeing
# Workflow output:  humans
# Workflow output:  to
# Workflow output:  focus
# Workflow output:  on
# Workflow output:  higher
# Workflow output: -value
# Workflow output:  work
# Workflow output: .
# Workflow output:  For
# Workflow output:  example
# Workflow output: ,
# Workflow output:  AI
# Workflow output:  agents
# Workflow output:  can
# Workflow output:  summarize
# Workflow output:  documents
# Workflow output: ,
# Workflow output:  manage
# Workflow output:  support
# Workflow output:  tickets
# Workflow output: ,
# Workflow output:  or
# Workflow output:  process
# Workflow output:  invoices
# Workflow output:  by
# Workflow output:  leveraging
# Workflow output:  large
# Workflow output:  language
# Workflow output:  models
# Workflow output:  (
# Workflow output: LL
# Workflow output: Ms
# Workflow output: )
# Workflow output:  that
# Workflow output:  understand
# Workflow output:  un
# Workflow output: structured
# Workflow output:  data
# Workflow output: ,
# Workflow output:  make
# Workflow output:  informed
# Workflow output:  decisions
# Workflow output: ,
# Workflow output:  and
# Workflow output:  generate
# Workflow output:  content
# Workflow output: .
# Workflow output:  These
# Workflow output:  agents
# Workflow output:  represent
# Workflow output:  a
# Workflow output:  new
# Workflow output:  frontier
# Workflow output:  in
# Workflow output:  automation
# Workflow output:  by
# Workflow output:  blending
# Workflow output:  human
# Workflow output: -like
# Workflow output:  understanding
# Workflow output:  with
# Workflow output:  computational
# Workflow output:  efficiency
# Workflow output: ,
# Workflow output:  enabling
# Workflow output:  smarter
# Workflow output:  workflows
# Workflow output:  and
# Workflow output:  interactions
# Workflow output: .
# Workflow output:  You
# Workflow output:  can
# Workflow output:  explore
# Workflow output:  the
# Workflow output:  foundational
# Workflow output:  concepts
# Workflow output:  and
# Workflow output:  get
# Workflow output:  an
# Workflow output:  overview
# Workflow output:  of
# Workflow output:  AI
# Workflow output:  agents
# Workflow output:  here
# Workflow output: :
# Workflow output:  [
# Workflow output: What's
# Workflow output:  AI
# Workflow output:  Agent
# Workflow output: ](
# Workflow output: https
# Workflow output: ://
# Workflow output: github
# Workflow output: .com
# Workflow output: /m
# Workflow output: icrosoft
# Workflow output: /
# Workflow output: ai
# Workflow output: -ag
# Workflow output: ents
# Workflow output: -for
# Workflow output: -b
# Workflow output: eg
# Workflow output: inners
# Workflow output: /tree
# Workflow output: /main
# Workflow output: /
# Workflow output: 01
# Workflow output: -int
# Workflow output: ro
# Workflow output: -to
# Workflow output: -ai
# Workflow output: -ag
# Workflow output: ents
# Workflow output: ).\
# Workflow output: n
# Workflow output: \n
# Workflow output: ##
# Workflow output:  Introducing
# Workflow output:  Azure
# Workflow output:  AI
# Workflow output:  Found
# Workflow output: ry
# Workflow output:  Agent
# Workflow output:  Service
# Workflow output: \n
# Workflow output: \n
# Workflow output: Azure
# Workflow output:  AI
# Workflow output:  Found
# Workflow output: ry
# Workflow output:  Agent
# Workflow output:  Service
# Workflow output:  is
# Workflow output:  a
# Workflow output:  powerful
# Workflow output:  platform
# Workflow output:  designed
# Workflow output:  to
# Workflow output:  support
# Workflow output:  the
# Workflow output:  development
# Workflow output: ,
# Workflow output:  deployment
# Workflow output: ,
# Workflow output:  and
# Workflow output:  management
# Workflow output:  of
# Workflow output:  AI
# Workflow output:  agents
# Workflow output:  at
# Workflow output:  scale
# Workflow output: .
# Workflow output:  It
# Workflow output:  integrates
# Workflow output:  various
# Workflow output:  models
# Workflow output: ,
# Workflow output:  tools
# Workflow output: ,
# Workflow output:  and
# Workflow output:  governance
# Workflow output:  mechanisms
# Workflow output:  into
# Workflow output:  a
# Workflow output:  unified
# Workflow output:  system
# Workflow output: ,
# Workflow output:  offering
# Workflow output:  a
# Workflow output:  robust
# Workflow output:  runtime
# Workflow output:  environment
# Workflow output:  for
# Workflow output:  intelligent
# Workflow output:  agents
# Workflow output: .
# Workflow output:  Unlike
# Workflow output:  simple
# Workflow output:  chat
# Workflow output: bots
# Workflow output: ,
# Workflow output:  Azure
# Workflow output:  AI
# Workflow output:  Found
# Workflow output: ry
# Workflow output:  Agents
# Workflow output:  enable
# Workflow output:  enterprises
# Workflow output:  to
# Workflow output:  automate
# Workflow output:  complex
# Workflow output:  workflows
# Workflow output:  with
# Workflow output:  security
# Workflow output: ,
# Workflow output:  scalability
# Workflow output: ,
# Workflow output:  and
# Workflow output:  trust
# Workflow output: worthiness
# Workflow output: .
# Workflow output:  This
# Workflow output:  service
# Workflow output:  orchestr
# Workflow output: ates
# Workflow output:  conversations
# Workflow output: ,
# Workflow output:  manages
# Workflow output:  tool
# Workflow output:  integrations
# Workflow output: ,
# Workflow output:  en
# Workflow output: forces
# Workflow output:  content
# Workflow output:  safety
# Workflow output:  protocols
# Workflow output: ,
# Workflow output:  and
# Workflow output:  inter
# Workflow output: connect
# Workflow output: s
# Workflow output:  with
# Workflow output:  identity
# Workflow output:  and
# Workflow output:  observ
# Workflow output: ability
# Workflow output:  frameworks
# Workflow output: .
# Workflow output:  Such
# Workflow output:  features
# Workflow output:  allow
# Workflow output:  businesses
# Workflow output:  to
# Workflow output:  move
# Workflow output:  from
# Workflow output:  prototypes
# Workflow output:  to
# Workflow output:  production
# Workflow output:  seamlessly
# Workflow output: ,
# Workflow output:  ensuring
# Workflow output:  that
# Workflow output:  AI
# Workflow output:  agents
# Workflow output:  remain
# Workflow output:  reliable
# Workflow output:  and
# Workflow output:  compliant
# Workflow output:  in
# Workflow output:  real
# Workflow output: -world
# Workflow output:  scenarios
# Workflow output: .\
# Workflow output: n
# Workflow output: \n
# Workflow output: For
# Workflow output:  businesses
# Workflow output: ,
# Workflow output:  this
# Workflow output:  means
# Workflow output:  leveraging
# Workflow output:  technologies
# Workflow output:  that
# Workflow output:  handle
# Workflow output:  repetitive
# Workflow output:  tasks
# Workflow output:  without
# Workflow output:  sacrificing
# Workflow output:  control
# Workflow output:  or
# Workflow output:  visibility
# Workflow output: .
# Workflow output:  Azure
# Workflow output:  AI
# Workflow output:  Found
# Workflow output: ry
# Workflow output:  thus
# Workflow output:  represents
# Workflow output:  a
# Workflow output:  leap
# Workflow output:  forward
# Workflow output:  in
# Workflow output:  making
# Workflow output:  L
# Workflow output: LM
# Workflow output: -powered
# Workflow output:  agents
# Workflow output:  practical
# Workflow output:  for
# Workflow output:  enterprise
# Workflow output:  use
# Workflow output:  cases
# Workflow output: ,
# Workflow output:  offering
# Workflow output:  a
# Workflow output:  scalable
# Workflow output:  infrastructure
# Workflow output:  that
# Workflow output:  abstracts
# Workflow output:  away
# Workflow output:  operational
# Workflow output:  complexities
# Workflow output: .
# Workflow output:  To
# Workflow output:  dive
# Workflow output:  deeper
# Workflow output:  into
# Workflow output:  the
# Workflow output:  capabilities
# Workflow output:  and
# Workflow output:  components
# Workflow output:  of
# Workflow output:  Azure
# Workflow output:  AI
# Workflow output:  Found
# Workflow output: ry
# Workflow output:  Agent
# Workflow output:  Service
# Workflow output: ,
# Workflow output:  visit
# Workflow output:  their
# Workflow output:  official
# Workflow output:  overview
# Workflow output:  page
# Workflow output: :
# Workflow output:  [
# Workflow output: Azure
# Workflow output:  AI
# Workflow output:  Found
# Workflow output: ry
# Workflow output:  Agent
# Workflow output:  Service
# Workflow output: ](
# Workflow output: https
# Workflow output: ://
# Workflow output: learn
# Workflow output: .microsoft
# Workflow output: .com
# Workflow output: /en
# Workflow output: -us
# Workflow output: /
# Workflow output: azure
# Workflow output: /
# Workflow output: ai
# Workflow output: -found
# Workflow output: ry
# Workflow output: /
# Workflow output: agents
# Workflow output: /
# Workflow output: overview
# Workflow output: ).\
# Workflow output: n
# Workflow output: \n
# Workflow output: ##
# Workflow output:  Microsoft
# Workflow output:  Agent
# Workflow output:  Framework
# Workflow output: \n
# Workflow output: \n
# Workflow output: The
# Workflow output:  Microsoft
# Workflow output:  Agent
# Workflow output:  Framework
# Workflow output:  is
# Workflow output:  an
# Workflow output:  open
# Workflow output: -source
# Workflow output:  toolkit
# Workflow output:  designed
# Workflow output:  to
# Workflow output:  accelerate
# Workflow output:  the
# Workflow output:  creation
# Workflow output:  and
# Workflow output:  lifecycle
# Workflow output:  management
# Workflow output:  of
# Workflow output:  AI
# Workflow output:  agents
# Workflow output: .
# Workflow output:  It
# Workflow output:  provides
# Workflow output:  templates
# Workflow output: ,
# Workflow output:  libraries
# Workflow output: ,
# Workflow output:  and
# Workflow output:  best
# Workflow output:  practices
# Workflow output:  that
# Workflow output:  simplify
# Workflow output:  integrating
# Workflow output:  agents
# Workflow output:  with
# Workflow output:  Azure
# Workflow output:  AI
# Workflow output:  Found
# Workflow output: ry
# Workflow output:  and
# Workflow output:  other
# Workflow output:  Microsoft
# Workflow output:  AI
# Workflow output:  services
# Workflow output: .
# Workflow output:  Developers
# Workflow output:  can
# Workflow output:  use
# Workflow output:  this
# Workflow output:  framework
# Workflow output:  to
# Workflow output:  build
# Workflow output:  intelligent
# Workflow output:  agents
# Workflow output:  that
# Workflow output:  are
# Workflow output:  persistent
# Workflow output: ,
# Workflow output:  context
# Workflow output: -aware
# Workflow output: ,
# Workflow output:  and
# Workflow output:  capable
# Workflow output:  of
# Workflow output:  interacting
# Workflow output:  with
# Workflow output:  a
# Workflow output:  variety
# Workflow output:  of
# Workflow output:  tools
# Workflow output:  and
# Workflow output:  services
# Workflow output: .\
# Workflow output: n
# Workflow output: \n
# Workflow output: The
# Workflow output:  framework
# Workflow output:  emphasizes
# Workflow output:  modular
# Workflow output: ity
# Workflow output:  and
# Workflow output:  scalability
# Workflow output: ,
# Workflow output:  supporting
# Workflow output:  multi
# Workflow output: -agent
# Workflow output:  systems
# Workflow output:  where
# Workflow output:  agents
# Workflow output:  can
# Workflow output:  collaborate
# Workflow output:  or
# Workflow output:  delegate
# Workflow output:  tasks
# Workflow output: .
# Workflow output:  It
# Workflow output:  also
# Workflow output:  addresses
# Workflow output:  security
# Workflow output: ,
# Workflow output:  compliance
# Workflow output: ,
# Workflow output:  and
# Workflow output:  operational
# Workflow output:  reliability
# Workflow output:  by
# Workflow output:  integrating
# Workflow output:  with
# Workflow output:  Azure
# Workflow output: ’s
# Workflow output:  identity
# Workflow output:  and
# Workflow output:  monitoring
# Workflow output:  services
# Workflow output: .
# Workflow output:  With
# Workflow output:  abundant
# Workflow output:  documentation
# Workflow output:  and
# Workflow output:  templates
# Workflow output:  available
# Workflow output: ,
# Workflow output:  the
# Workflow output:  Microsoft
# Workflow output:  Agent
# Workflow output:  Framework
# Workflow output:  helps
# Workflow output:  streamline
# Workflow output:  the
# Workflow output:  development
# Workflow output:  process
# Workflow output: ,
# Workflow output:  reducing
# Workflow output:  the
# Workflow output:  complexity
# Workflow output:  involved
# Workflow output:  in
# Workflow output:  managing
# Workflow output:  AI
# Workflow output: -driven
# Workflow output:  workflows
# Workflow output: .\
# Workflow output: n
# Workflow output: \n
# Workflow output: For
# Workflow output:  those
# Workflow output:  interested
# Workflow output:  in
# Workflow output:  exploring
# Workflow output:  the
# Workflow output:  architecture
# Workflow output: ,
# Workflow output:  documentation
# Workflow output: ,
# Workflow output:  and
# Workflow output:  useful
# Workflow output:  templates
# Workflow output:  that
# Workflow output:  can
# Workflow output:  jump
# Workflow output: start
# Workflow output:  AI
# Workflow output:  agent
# Workflow output:  development
# Workflow output: ,
# Workflow output:  the
# Workflow output:  Microsoft
# Workflow output:  Agent
# Workflow output:  Framework
# Workflow output:  repository
# Workflow output:  offers
# Workflow output:  valuable
# Workflow output:  insights
# Workflow output: :
# Workflow output:  [
# Workflow output: Microsoft
# Workflow output:  Agent
# Workflow output:  Framework
# Workflow output: ](
# Workflow output: https
# Workflow output: ://
# Workflow output: github
# Workflow output: .com
# Workflow output: /m
# Workflow output: icrosoft
# Workflow output: /
# Workflow output: agent
# Workflow output: -framework
# Workflow output: /tree
# Workflow output: /main
# Workflow output: /docs
# Workflow output: /docs
# Workflow output: -
# Workflow output: templates
# Workflow output: ).\
# Workflow output: n
# Workflow output: \n
# Workflow output: ---
# Workflow output: \
# Workflow output: n
# Workflow output: \n
# Workflow output: In
# Workflow output:  summary
# Workflow output: ,
# Workflow output:  AI
# Workflow output:  Agents
# Workflow output:  represent
# Workflow output:  the
# Workflow output:  future
# Workflow output:  of
# Workflow output:  automation
# Workflow output:  by
# Workflow output:  combining
# Workflow output:  autonomy
# Workflow output: ,
# Workflow output:  intelligence
# Workflow output: ,
# Workflow output:  and
# Workflow output:  connectivity
# Workflow output: .
# Workflow output:  Microsoft's
# Workflow output:  ecosystem
# Workflow output: —including
# Workflow output:  AI
# Workflow output:  Agents
# Workflow output:  basics
# Workflow output: ,
# Workflow output:  Azure
# Workflow output:  AI
# Workflow output:  Found
# Workflow output: ry
# Workflow output:  Agent
# Workflow output:  Service
# Workflow output: ,
# Workflow output:  and
# Workflow output:  Microsoft
# Workflow output:  Agent
# Workflow output:  Framework
# Workflow output: —
# Workflow output: provid
# Workflow output: es
# Workflow output:  a
# Workflow output:  comprehensive
# Workflow output:  set
# Workflow output:  of
# Workflow output:  tools
# Workflow output:  and
# Workflow output:  platforms
# Workflow output:  to
# Workflow output:  build
# Workflow output: ,
# Workflow output:  deploy
# Workflow output: ,
# Workflow output:  and
# Workflow output:  operate
# Workflow output:  intelligent
# Workflow output:  agents
# Workflow output:  safely
# Workflow output:  and
# Workflow output:  efficiently
# Workflow output: .
# Workflow output:  By
# Workflow output:  leveraging
# Workflow output:  these
# Workflow output:  technologies
# Workflow output: ,
# Workflow output:  organizations
# Workflow output:  can
# Workflow output:  usher
# Workflow output:  in
# Workflow output:  new
# Workflow output:  levels
# Workflow output:  of
# Workflow output:  productivity
# Workflow output:  and
# Workflow output:  innovation
# Workflow output:  through
# Workflow output:  trustworthy
# Workflow output:  AI
# Workflow output: -driven
# Workflow output:  automation
# Workflow output: ."
#
# Workflow output: }
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output: [AgentExecutorResponse(executor_id='evangelist_agent', agent_response=<agent_framework._types.AgentResponse object at 0x1237e4d40>, full_conversation=[<agent_framework._types.ChatMessage object at 0x122e684d0>, <agent_framework._types.ChatMessage object at 0x122e69790>])]
# Workflow output: None
# Workflow output: AgentExecutorResponse(executor_id='evangelist_agent', agent_response=<agent_framework._types.AgentResponse object at 0x124556120>, full_conversation=[<agent_framework._types.ChatMessage object at 0x12370d0d0>, <agent_framework._types.ChatMessage object at 0x120a20a70>])
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output: {
#
# Workflow output:
# Workflow output:  "
# Workflow output: review
# Workflow output: _result
# Workflow output: ":
# Workflow output:  "
# Workflow output: Yes
# Workflow output: ",
#
# Workflow output:
# Workflow output:  "
# Workflow output: reason
# Workflow output: ":
# Workflow output:  "
# Workflow output: The
# Workflow output:  content
# Workflow output:  is
# Workflow output:  good
# Workflow output: ",
#
# Workflow output:
# Workflow output:  "
# Workflow output: draft
# Workflow output: _content
# Workflow output: ":
# Workflow output:  "#
# Workflow output:  Introducing
# Workflow output:  AI
# Workflow output:  Agents
# Workflow output: :
# Workflow output:  Empower
# Workflow output: ing
# Workflow output:  Intelligent
# Workflow output:  Automation
# Workflow output: \n
# Workflow output: \n
# Workflow output: ##
# Workflow output:  What
# Workflow output:  is
# Workflow output:  an
# Workflow output:  AI
# Workflow output:  Agent
# Workflow output: ?\
# Workflow output: n
# Workflow output: \n
# Workflow output: An
# Workflow output:  AI
# Workflow output:  Agent
# Workflow output:  is
# Workflow output:  a
# Workflow output:  sophisticated
# Workflow output:  software
# Workflow output:  entity
# Workflow output:  that
# Workflow output:  can
# Workflow output:  autonom
# Workflow output: ously
# Workflow output:  perform
# Workflow output:  tasks
# Workflow output:  by
# Workflow output:  making
# Workflow output:  decisions
# Workflow output: ,
# Workflow output:  invoking
# Workflow output:  tools
# Workflow output: ,
# Workflow output:  and
# Workflow output:  participating
# Workflow output:  in
# Workflow output:  workflows
# Workflow output: .
# Workflow output:  They
# Workflow output:  operate
# Workflow output:  either
# Workflow output:  independently
# Workflow output:  or
# Workflow output:  collaboratively
# Workflow output:  with
# Workflow output:  other
# Workflow output:  agents
# Workflow output:  or
# Workflow output:  humans
# Workflow output:  to
# Workflow output:  accomplish
# Workflow output:  specific
# Workflow output:  goals
# Workflow output: .
# Workflow output:  This
# Workflow output:  concept
# Workflow output:  forms
# Workflow output:  the
# Workflow output:  foundation
# Workflow output:  of
# Workflow output:  many
# Workflow output:  modern
# Workflow output:  intelligent
# Workflow output:  systems
# Workflow output: ,
# Workflow output:  where
# Workflow output:  agents
# Workflow output:  not
# Workflow output:  only
# Workflow output:  follow
# Workflow output:  predefined
# Workflow output:  instructions
# Workflow output:  but
# Workflow output:  also
# Workflow output:  learn
# Workflow output:  and
# Workflow output:  adapt
# Workflow output:  based
# Workflow output:  on
# Workflow output:  context
# Workflow output:  and
# Workflow output:  data
# Workflow output: .
# Workflow output:  Microsoft's
# Workflow output:  AI
# Workflow output:  Agents
# Workflow output:  for
# Workflow output:  Beginners
# Workflow output:  repository
# Workflow output:  offers
# Workflow output:  a
# Workflow output:  comprehensive
# Workflow output:  introduction
# Workflow output:  to
# Workflow output:  these
# Workflow output:  concepts
# Workflow output: ,
# Workflow output:  explaining
# Workflow output:  that
# Workflow output:  AI
# Workflow output:  agents
# Workflow output:  are
# Workflow output:  designed
# Workflow output:  to
# Workflow output:  automate
# Workflow output:  repetitive
# Workflow output:  and
# Workflow output:  predictable
# Workflow output:  tasks
# Workflow output: ,
# Workflow output:  freeing
# Workflow output:  humans
# Workflow output:  to
# Workflow output:  focus
# Workflow output:  on
# Workflow output:  higher
# Workflow output: -value
# Workflow output:  work
# Workflow output: .
# Workflow output:  For
# Workflow output:  example
# Workflow output: ,
# Workflow output:  AI
# Workflow output:  agents
# Workflow output:  can
# Workflow output:  summarize
# Workflow output:  documents
# Workflow output: ,
# Workflow output:  manage
# Workflow output:  support
# Workflow output:  tickets
# Workflow output: ,
# Workflow output:  or
# Workflow output:  process
# Workflow output:  invoices
# Workflow output:  by
# Workflow output:  leveraging
# Workflow output:  large
# Workflow output:  language
# Workflow output:  models
# Workflow output:  (
# Workflow output: LL
# Workflow output: Ms
# Workflow output: )
# Workflow output:  that
# Workflow output:  understand
# Workflow output:  un
# Workflow output: structured
# Workflow output:  data
# Workflow output: ,
# Workflow output:  make
# Workflow output:  informed
# Workflow output:  decisions
# Workflow output: ,
# Workflow output:  and
# Workflow output:  generate
# Workflow output:  content
# Workflow output: .
# Workflow output:  These
# Workflow output:  agents
# Workflow output:  represent
# Workflow output:  a
# Workflow output:  new
# Workflow output:  frontier
# Workflow output:  in
# Workflow output:  automation
# Workflow output:  by
# Workflow output:  blending
# Workflow output:  human
# Workflow output: -like
# Workflow output:  understanding
# Workflow output:  with
# Workflow output:  computational
# Workflow output:  efficiency
# Workflow output: ,
# Workflow output:  enabling
# Workflow output:  smarter
# Workflow output:  workflows
# Workflow output:  and
# Workflow output:  interactions
# Workflow output: .
# Workflow output:  You
# Workflow output:  can
# Workflow output:  explore
# Workflow output:  the
# Workflow output:  foundational
# Workflow output:  concepts
# Workflow output:  and
# Workflow output:  get
# Workflow output:  an
# Workflow output:  overview
# Workflow output:  of
# Workflow output:  AI
# Workflow output:  agents
# Workflow output:  here
# Workflow output: :
# Workflow output:  [
# Workflow output: What's
# Workflow output:  AI
# Workflow output:  Agent
# Workflow output: ](
# Workflow output: https
# Workflow output: ://
# Workflow output: github
# Workflow output: .com
# Workflow output: /m
# Workflow output: icrosoft
# Workflow output: /
# Workflow output: ai
# Workflow output: -ag
# Workflow output: ents
# Workflow output: -for
# Workflow output: -b
# Workflow output: eg
# Workflow output: inners
# Workflow output: /tree
# Workflow output: /main
# Workflow output: /
# Workflow output: 01
# Workflow output: -int
# Workflow output: ro
# Workflow output: -to
# Workflow output: -ai
# Workflow output: -ag
# Workflow output: ents
# Workflow output: ).\
# Workflow output: n
# Workflow output: \n
# Workflow output: ##
# Workflow output:  Introducing
# Workflow output:  Azure
# Workflow output:  AI
# Workflow output:  Found
# Workflow output: ry
# Workflow output:  Agent
# Workflow output:  Service
# Workflow output: \n
# Workflow output: \n
# Workflow output: Azure
# Workflow output:  AI
# Workflow output:  Found
# Workflow output: ry
# Workflow output:  Agent
# Workflow output:  Service
# Workflow output:  is
# Workflow output:  a
# Workflow output:  powerful
# Workflow output:  platform
# Workflow output:  designed
# Workflow output:  to
# Workflow output:  support
# Workflow output:  the
# Workflow output:  development
# Workflow output: ,
# Workflow output:  deployment
# Workflow output: ,
# Workflow output:  and
# Workflow output:  management
# Workflow output:  of
# Workflow output:  AI
# Workflow output:  agents
# Workflow output:  at
# Workflow output:  scale
# Workflow output: .
# Workflow output:  It
# Workflow output:  integrates
# Workflow output:  various
# Workflow output:  models
# Workflow output: ,
# Workflow output:  tools
# Workflow output: ,
# Workflow output:  and
# Workflow output:  governance
# Workflow output:  mechanisms
# Workflow output:  into
# Workflow output:  a
# Workflow output:  unified
# Workflow output:  system
# Workflow output: ,
# Workflow output:  offering
# Workflow output:  a
# Workflow output:  robust
# Workflow output:  runtime
# Workflow output:  environment
# Workflow output:  for
# Workflow output:  intelligent
# Workflow output:  agents
# Workflow output: .
# Workflow output:  Unlike
# Workflow output:  simple
# Workflow output:  chat
# Workflow output: bots
# Workflow output: ,
# Workflow output:  Azure
# Workflow output:  AI
# Workflow output:  Found
# Workflow output: ry
# Workflow output:  Agents
# Workflow output:  enable
# Workflow output:  enterprises
# Workflow output:  to
# Workflow output:  automate
# Workflow output:  complex
# Workflow output:  workflows
# Workflow output:  with
# Workflow output:  security
# Workflow output: ,
# Workflow output:  scalability
# Workflow output: ,
# Workflow output:  and
# Workflow output:  trust
# Workflow output: worthiness
# Workflow output: .
# Workflow output:  This
# Workflow output:  service
# Workflow output:  orchestr
# Workflow output: ates
# Workflow output:  conversations
# Workflow output: ,
# Workflow output:  manages
# Workflow output:  tool
# Workflow output:  integrations
# Workflow output: ,
# Workflow output:  en
# Workflow output: forces
# Workflow output:  content
# Workflow output:  safety
# Workflow output:  protocols
# Workflow output: ,
# Workflow output:  and
# Workflow output:  inter
# Workflow output: connect
# Workflow output: s
# Workflow output:  with
# Workflow output:  identity
# Workflow output:  and
# Workflow output:  observ
# Workflow output: ability
# Workflow output:  frameworks
# Workflow output: .
# Workflow output:  Such
# Workflow output:  features
# Workflow output:  allow
# Workflow output:  businesses
# Workflow output:  to
# Workflow output:  move
# Workflow output:  from
# Workflow output:  prototypes
# Workflow output:  to
# Workflow output:  production
# Workflow output:  seamlessly
# Workflow output: ,
# Workflow output:  ensuring
# Workflow output:  that
# Workflow output:  AI
# Workflow output:  agents
# Workflow output:  remain
# Workflow output:  reliable
# Workflow output:  and
# Workflow output:  compliant
# Workflow output:  in
# Workflow output:  real
# Workflow output: -world
# Workflow output:  scenarios
# Workflow output: .\
# Workflow output: n
# Workflow output: \n
# Workflow output: For
# Workflow output:  businesses
# Workflow output: ,
# Workflow output:  this
# Workflow output:  means
# Workflow output:  leveraging
# Workflow output:  technologies
# Workflow output:  that
# Workflow output:  handle
# Workflow output:  repetitive
# Workflow output:  tasks
# Workflow output:  without
# Workflow output:  sacrificing
# Workflow output:  control
# Workflow output:  or
# Workflow output:  visibility
# Workflow output: .
# Workflow output:  Azure
# Workflow output:  AI
# Workflow output:  Found
# Workflow output: ry
# Workflow output:  thus
# Workflow output:  represents
# Workflow output:  a
# Workflow output:  leap
# Workflow output:  forward
# Workflow output:  in
# Workflow output:  making
# Workflow output:  L
# Workflow output: LM
# Workflow output: -powered
# Workflow output:  agents
# Workflow output:  practical
# Workflow output:  for
# Workflow output:  enterprise
# Workflow output:  use
# Workflow output:  cases
# Workflow output: ,
# Workflow output:  offering
# Workflow output:  a
# Workflow output:  scalable
# Workflow output:  infrastructure
# Workflow output:  that
# Workflow output:  abstracts
# Workflow output:  away
# Workflow output:  operational
# Workflow output:  complexities
# Workflow output: .
# Workflow output:  To
# Workflow output:  dive
# Workflow output:  deeper
# Workflow output:  into
# Workflow output:  the
# Workflow output:  capabilities
# Workflow output:  and
# Workflow output:  components
# Workflow output:  of
# Workflow output:  Azure
# Workflow output:  AI
# Workflow output:  Found
# Workflow output: ry
# Workflow output:  Agent
# Workflow output:  Service
# Workflow output: ,
# Workflow output:  visit
# Workflow output:  their
# Workflow output:  official
# Workflow output:  overview
# Workflow output:  page
# Workflow output: :
# Workflow output:  [
# Workflow output: Azure
# Workflow output:  AI
# Workflow output:  Found
# Workflow output: ry
# Workflow output:  Agent
# Workflow output:  Service
# Workflow output: ](
# Workflow output: https
# Workflow output: ://
# Workflow output: learn
# Workflow output: .microsoft
# Workflow output: .com
# Workflow output: /en
# Workflow output: -us
# Workflow output: /
# Workflow output: azure
# Workflow output: /
# Workflow output: ai
# Workflow output: -found
# Workflow output: ry
# Workflow output: /
# Workflow output: agents
# Workflow output: /
# Workflow output: overview
# Workflow output: ).\
# Workflow output: n
# Workflow output: \n
# Workflow output: ##
# Workflow output:  Microsoft
# Workflow output:  Agent
# Workflow output:  Framework
# Workflow output: \n
# Workflow output: \n
# Workflow output: The
# Workflow output:  Microsoft
# Workflow output:  Agent
# Workflow output:  Framework
# Workflow output:  is
# Workflow output:  an
# Workflow output:  open
# Workflow output: -source
# Workflow output:  toolkit
# Workflow output:  designed
# Workflow output:  to
# Workflow output:  accelerate
# Workflow output:  the
# Workflow output:  creation
# Workflow output:  and
# Workflow output:  lifecycle
# Workflow output:  management
# Workflow output:  of
# Workflow output:  AI
# Workflow output:  agents
# Workflow output: .
# Workflow output:  It
# Workflow output:  provides
# Workflow output:  templates
# Workflow output: ,
# Workflow output:  libraries
# Workflow output: ,
# Workflow output:  and
# Workflow output:  best
# Workflow output:  practices
# Workflow output:  that
# Workflow output:  simplify
# Workflow output:  integrating
# Workflow output:  agents
# Workflow output:  with
# Workflow output:  Azure
# Workflow output:  AI
# Workflow output:  Found
# Workflow output: ry
# Workflow output:  and
# Workflow output:  other
# Workflow output:  Microsoft
# Workflow output:  AI
# Workflow output:  services
# Workflow output: .
# Workflow output:  Developers
# Workflow output:  can
# Workflow output:  use
# Workflow output:  this
# Workflow output:  framework
# Workflow output:  to
# Workflow output:  build
# Workflow output:  intelligent
# Workflow output:  agents
# Workflow output:  that
# Workflow output:  are
# Workflow output:  persistent
# Workflow output: ,
# Workflow output:  context
# Workflow output: -aware
# Workflow output: ,
# Workflow output:  and
# Workflow output:  capable
# Workflow output:  of
# Workflow output:  interacting
# Workflow output:  with
# Workflow output:  a
# Workflow output:  variety
# Workflow output:  of
# Workflow output:  tools
# Workflow output:  and
# Workflow output:  services
# Workflow output: .\
# Workflow output: n
# Workflow output: \n
# Workflow output: The
# Workflow output:  framework
# Workflow output:  emphasizes
# Workflow output:  modular
# Workflow output: ity
# Workflow output:  and
# Workflow output:  scalability
# Workflow output: ,
# Workflow output:  supporting
# Workflow output:  multi
# Workflow output: -agent
# Workflow output:  systems
# Workflow output:  where
# Workflow output:  agents
# Workflow output:  can
# Workflow output:  collaborate
# Workflow output:  or
# Workflow output:  delegate
# Workflow output:  tasks
# Workflow output: .
# Workflow output:  It
# Workflow output:  also
# Workflow output:  addresses
# Workflow output:  security
# Workflow output: ,
# Workflow output:  compliance
# Workflow output: ,
# Workflow output:  and
# Workflow output:  operational
# Workflow output:  reliability
# Workflow output:  by
# Workflow output:  integrating
# Workflow output:  with
# Workflow output:  Azure
# Workflow output: ’s
# Workflow output:  identity
# Workflow output:  and
# Workflow output:  monitoring
# Workflow output:  services
# Workflow output: .
# Workflow output:  With
# Workflow output:  abundant
# Workflow output:  documentation
# Workflow output:  and
# Workflow output:  templates
# Workflow output:  available
# Workflow output: ,
# Workflow output:  the
# Workflow output:  Microsoft
# Workflow output:  Agent
# Workflow output:  Framework
# Workflow output:  helps
# Workflow output:  streamline
# Workflow output:  the
# Workflow output:  development
# Workflow output:  process
# Workflow output: ,
# Workflow output:  reducing
# Workflow output:  the
# Workflow output:  complexity
# Workflow output:  involved
# Workflow output:  in
# Workflow output:  managing
# Workflow output:  AI
# Workflow output: -driven
# Workflow output:  workflows
# Workflow output: .\
# Workflow output: n
# Workflow output: \n
# Workflow output: For
# Workflow output:  those
# Workflow output:  interested
# Workflow output:  in
# Workflow output:  exploring
# Workflow output:  the
# Workflow output:  architecture
# Workflow output: ,
# Workflow output:  documentation
# Workflow output: ,
# Workflow output:  and
# Workflow output:  useful
# Workflow output:  templates
# Workflow output:  that
# Workflow output:  can
# Workflow output:  jump
# Workflow output: start
# Workflow output:  AI
# Workflow output:  agent
# Workflow output:  development
# Workflow output: ,
# Workflow output:  the
# Workflow output:  Microsoft
# Workflow output:  Agent
# Workflow output:  Framework
# Workflow output:  repository
# Workflow output:  offers
# Workflow output:  valuable
# Workflow output:  insights
# Workflow output: :
# Workflow output:  [
# Workflow output: Microsoft
# Workflow output:  Agent
# Workflow output:  Framework
# Workflow output: ](
# Workflow output: https
# Workflow output: ://
# Workflow output: github
# Workflow output: .com
# Workflow output: /m
# Workflow output: icrosoft
# Workflow output: /
# Workflow output: agent
# Workflow output: -framework
# Workflow output: /tree
# Workflow output: /main
# Workflow output: /docs
# Workflow output: /docs
# Workflow output: -
# Workflow output: templates
# Workflow output: ).\
# Workflow output: n
# Workflow output: \n
# Workflow output: ---
# Workflow output: \
# Workflow output: n
# Workflow output: \n
# Workflow output: In
# Workflow output:  summary
# Workflow output: ,
# Workflow output:  AI
# Workflow output:  Agents
# Workflow output:  represent
# Workflow output:  the
# Workflow output:  future
# Workflow output:  of
# Workflow output:  automation
# Workflow output:  by
# Workflow output:  combining
# Workflow output:  autonomy
# Workflow output: ,
# Workflow output:  intelligence
# Workflow output: ,
# Workflow output:  and
# Workflow output:  connectivity
# Workflow output: .
# Workflow output:  Microsoft's
# Workflow output:  ecosystem
# Workflow output: —including
# Workflow output:  AI
# Workflow output:  Agents
# Workflow output:  basics
# Workflow output: ,
# Workflow output:  Azure
# Workflow output:  AI
# Workflow output:  Found
# Workflow output: ry
# Workflow output:  Agent
# Workflow output:  Service
# Workflow output: ,
# Workflow output:  and
# Workflow output:  Microsoft
# Workflow output:  Agent
# Workflow output:  Framework
# Workflow output: —
# Workflow output: provid
# Workflow output: es
# Workflow output:  a
# Workflow output:  comprehensive
# Workflow output:  set
# Workflow output:  of
# Workflow output:  tools
# Workflow output:  and
# Workflow output:  platforms
# Workflow output:  to
# Workflow output:  build
# Workflow output: ,
# Workflow output:  deploy
# Workflow output: ,
# Workflow output:  and
# Workflow output:  operate
# Workflow output:  intelligent
# Workflow output:  agents
# Workflow output:  safely
# Workflow output:  and
# Workflow output:  efficiently
# Workflow output: .
# Workflow output:  By
# Workflow output:  leveraging
# Workflow output:  these
# Workflow output:  technologies
# Workflow output: ,
# Workflow output:  organizations
# Workflow output:  can
# Workflow output:  usher
# Workflow output:  in
# Workflow output:  new
# Workflow output:  levels
# Workflow output:  of
# Workflow output:  productivity
# Workflow output:  and
# Workflow output:  innovation
# Workflow output:  through
# Workflow output:  trustworthy
# Workflow output:  AI
# Workflow output: -driven
# Workflow output:  automation
# Workflow output: ."
#
# Workflow output: }
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output: [AgentExecutorResponse(executor_id='reviewer_agent', agent_response=<agent_framework._types.AgentResponse object at 0x1242694f0>, full_conversation=[<agent_framework._types.ChatMessage object at 0x122e684d0>, <agent_framework._types.ChatMessage object at 0x122e69790>, <agent_framework._types.ChatMessage object at 0x1233f5730>])]
# Workflow output: None
# Workflow output: None
# Raw response from reviewer agent: {
#   "review_result": "Yes",
#   "reason": "The content is good",
#   "draft_content": "# Introducing AI Agents: Empowering Intelligent Automation\n\n## What is an AI Agent?\n\nAn AI Agent is a sophisticated software entity that can autonomously perform tasks by making decisions, invoking tools, and participating in workflows. They operate either independently or collaboratively with other agents or humans to accomplish specific goals. This concept forms the foundation of many modern intelligent systems, where agents not only follow predefined instructions but also learn and adapt based on context and data. Microsoft's AI Agents for Beginners repository offers a comprehensive introduction to these concepts, explaining that AI agents are designed to automate repetitive and predictable tasks, freeing humans to focus on higher-value work. For example, AI agents can summarize documents, manage support tickets, or process invoices by leveraging large language models (LLMs) that understand unstructured data, make informed decisions, and generate content. These agents represent a new frontier in automation by blending human-like understanding with computational efficiency, enabling smarter workflows and interactions. You can explore the foundational concepts and get an overview of AI agents here: [What's AI Agent](https://github.com/microsoft/ai-agents-for-beginners/tree/main/01-intro-to-ai-agents).\n\n## Introducing Azure AI Foundry Agent Service\n\nAzure AI Foundry Agent Service is a powerful platform designed to support the development, deployment, and management of AI agents at scale. It integrates various models, tools, and governance mechanisms into a unified system, offering a robust runtime environment for intelligent agents. Unlike simple chatbots, Azure AI Foundry Agents enable enterprises to automate complex workflows with security, scalability, and trustworthiness. This service orchestrates conversations, manages tool integrations, enforces content safety protocols, and interconnects with identity and observability frameworks. Such features allow businesses to move from prototypes to production seamlessly, ensuring that AI agents remain reliable and compliant in real-world scenarios.\n\nFor businesses, this means leveraging technologies that handle repetitive tasks without sacrificing control or visibility. Azure AI Foundry thus represents a leap forward in making LLM-powered agents practical for enterprise use cases, offering a scalable infrastructure that abstracts away operational complexities. To dive deeper into the capabilities and components of Azure AI Foundry Agent Service, visit their official overview page: [Azure AI Foundry Agent Service](https://learn.microsoft.com/en-us/azure/ai-foundry/agents/overview).\n\n## Microsoft Agent Framework\n\nThe Microsoft Agent Framework is an open-source toolkit designed to accelerate the creation and lifecycle management of AI agents. It provides templates, libraries, and best practices that simplify integrating agents with Azure AI Foundry and other Microsoft AI services. Developers can use this framework to build intelligent agents that are persistent, context-aware, and capable of interacting with a variety of tools and services.\n\nThe framework emphasizes modularity and scalability, supporting multi-agent systems where agents can collaborate or delegate tasks. It also addresses security, compliance, and operational reliability by integrating with Azure’s identity and monitoring services. With abundant documentation and templates available, the Microsoft Agent Framework helps streamline the development process, reducing the complexity involved in managing AI-driven workflows.\n\nFor those interested in exploring the architecture, documentation, and useful templates that can jumpstart AI agent development, the Microsoft Agent Framework repository offers valuable insights: [Microsoft Agent Framework](https://github.com/microsoft/agent-framework/tree/main/docs/docs-templates).\n\n---\n\nIn summary, AI Agents represent the future of automatio ...
# }
# Workflow output: AgentExecutorResponse(executor_id='reviewer_agent', agent_response=<agent_framework._types.AgentResponse object at 0x120a20a40>, full_conversation=[<agent_framework._types.ChatMessage object at 0x120a20380>, <agent_framework._types.ChatMessage object at 0x120a20a70>, <agent_framework._types.ChatMessage object at 0x1245a27e0>])
# ...
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output: The
# Workflow output:  tutorial
# Workflow output:  draft
# Workflow output:  has
# Workflow output:  been
# Workflow output:  saved
# Workflow output:  as
# Workflow output:  a
# Workflow output:  Markdown
# Workflow output:  file
# Workflow output:  named
# Workflow output:  `
# Workflow output: 202
# Workflow output: 602
# Workflow output: 051
# Workflow output: 018
# Workflow output: 23
# Workflow output: .md
# Workflow output: `.
#
#
# Workflow output: [
# Workflow output: Download
# Workflow output:  the
# Workflow output:  Markdown
# Workflow output:  file
# Workflow output: ](
# Workflow output: sandbox
# Workflow output: :/
# Workflow output: mnt
# Workflow output: /data
# Workflow output: /
# Workflow output: 202
# Workflow output: 602
# Workflow output: 051
# Workflow output: 018
# Workflow output: 23
# Workflow output: .md
# Workflow output: )
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output:
# Workflow output: [AgentExecutorResponse(executor_id='publisher_agent', agent_response=<agent_framework._types.AgentResponse object at 0x124aca8a0>, full_conversation=[<agent_framework._types.ChatMessage object at 0x124862e70>, <agent_framework._types.ChatMessage object at 0x124d08860>])]
# Workflow output: None
# Workflow output: None
# Workflow output: None
# Workflow output: None
# done
