# %% [markdown]
# # ⚡ Concurrent Agent Workflows with GitHub Models (Python)
#
# ## 📋 Advanced Parallel Processing Tutorial
#
# This notebook demonstrates **concurrent workflow patterns** using the Microsoft Agent Framework. You'll learn how to build high-performance, parallel processing workflows where multiple AI agents execute simultaneously, dramatically improving throughput and enabling sophisticated multi-threaded business processes.
#
# ## 🎯 Learning Objectives
#
# ### 🚀 **Concurrent Processing Fundamentals**
# - **Parallel Agent Execution**: Run multiple agents simultaneously for maximum efficiency
# - **Workflow Orchestration**: Coordinate concurrent operations while maintaining data consistency
# - **Performance Optimization**: Achieve significant speedup through parallel processing
# - **Resource Management**: Efficiently utilize AI model resources across concurrent operations
#
# ### 🏗️ **Advanced Concurrency Patterns**
# - **Fork-Join Processing**: Split work across multiple agents and merge results
# - **Pipeline Parallelism**: Overlapping execution stages for continuous throughput
# - **Load Balancing**: Distribute work evenly across available agent resources
# - **Synchronization Points**: Coordinate concurrent agents at critical workflow stages
#
# ### 🏢 **Enterprise Concurrent Applications**
# - **High-Volume Document Processing**: Process multiple documents simultaneously
# - **Real-Time Content Analysis**: Concurrent analysis of incoming data streams
# - **Batch Processing Optimization**: Maximize throughput for large-scale operations
# - **Multi-Modal Analysis**: Parallel processing of different content types (text, images, data)
#
# ## ⚙️ Prerequisites & Setup
#
# ### 📦 **Required Dependencies**
#
# Install Agent Framework with concurrent workflow capabilities:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **GitHub Models Configuration**
#
# **Environment Setup (.env file):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **Concurrent Processing Considerations:**
# - **Rate Limits**: Monitor GitHub Models API rate limits for concurrent requests
# - **Resource Usage**: Consider memory and CPU usage with multiple concurrent agents
# - **Error Handling**: Implement robust error recovery for parallel operations
#
# ### 🏗️ **Concurrent Workflow Architecture**
#
# ```mermaid
# graph TD
#     A[Workflow Start] --> B[Concurrent Execution]
#     B --> C[Agent Pool 1]
#     B --> D[Agent Pool 2]
#     B --> E[Agent Pool 3]
#     C --> F[Result Aggregation]
#     D --> F
#     E --> F
#     F --> G[Final Output]
#
#     H[GitHub Models API] --> C
#     H --> D
#     H --> E
# ```
#
# **Key Benefits:**
# - **⚡ Performance**: Significant speedup through parallel execution
# - **📈 Scalability**: Handle increased workloads without proportional time increase
# - **🔄 Efficiency**: Better utilization of available computational resources
# - **🎯 Throughput**: Process more work in the same amount of time
#
# ## 🎨 **Concurrent Workflow Design Patterns**
#
# ### 🔍 **Research & Analysis Pipeline**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **Data Processing Workflow**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **Content Creation Pipeline**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **Multi-Stage Processing**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **Enterprise Performance Benefits**
#
# ### ⚡ **Throughput Optimization**
# - **Parallel Execution**: Multiple agents working simultaneously
# - **Resource Utilization**: Maximum efficiency of available AI model capacity
# - **Time Reduction**: Significant decrease in total processing time
# - **Scalable Architecture**: Easily add more concurrent agents as needed
#
# ### 🛡️ **Reliability & Resilience**
# - **Fault Tolerance**: Individual agent failures don't stop the entire workflow
# - **Error Isolation**: Problems in one concurrent branch don't affect others
# - **Graceful Degradation**: System continues operating even with reduced agent capacity
# - **Recovery Mechanisms**: Automatic retry and error handling for failed operations
#
# ### 📊 **Monitoring & Observability**
# - **Concurrent Execution Tracking**: Monitor progress of all parallel operations
# - **Performance Metrics**: Measure speedup and efficiency gains
# - **Resource Usage Analytics**: Optimize concurrent agent allocation
# - **Bottleneck Identification**: Find and resolve performance constraints
#
# Let's build high-performance concurrent AI workflows! 🚀

# %%
####### Linux / MacOS Setup Instructions #######

####### Linux Instructions #######
# ! sudo apt update 
# ! sudo apt install graphviz -y

####### macOS Instructions #######
# ! brew install graphviz

# %%
# ! pip install -r ../../../Installation/requirements.txt -U
#

# %%
import os
from typing import Any

from agent_framework import ChatMessage, ConcurrentBuilder,WorkflowViz
from agent_framework.openai import OpenAIChatClient

# %%
chat_client = OpenAIChatClient(base_url=os.environ.get("GITHUB_ENDPOINT"), api_key=os.environ.get("GITHUB_TOKEN"), model_id="gpt-4o" )

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent   = chat_client.as_agent(
        instructions=(
           ResearcherAgentInstructions
        ),
        name=ResearcherAgentName,
    )

plan_agent = chat_client.as_agent(
        instructions=(
            PlanAgentInstructions
        ),
        name=PlanAgentName,
    )

# %%
workflow = ConcurrentBuilder().participants([research_agent, plan_agent]).build()

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
svg_file = viz.export(format="svg")
print(f"SVG file saved to: {svg_file}")
# Out:
# Generating workflow visualization...
# Mermaid string:
# =======
# flowchart TD
#   dispatcher["dispatcher (Start)"];
#   Researcher_Agent["Researcher-Agent"];
#   Plan_Agent["Plan-Agent"];
#   aggregator["aggregator"];
#   fan_in__aggregator__69d73de8((fan-in))
#   Plan_Agent --> fan_in__aggregator__69d73de8;
#   Researcher_Agent --> fan_in__aggregator__69d73de8;
#   fan_in__aggregator__69d73de8 --> aggregator;
#   dispatcher --> Researcher_Agent;
#   dispatcher --> Plan_Agent;
# =======
# DiGraph string:
# =======
# digraph Workflow {
#   rankdir=TD;
#   node [shape=box, style=filled, fillcolor=lightblue];
#   edge [color=black, arrowhead=vee];
#
#   "dispatcher" [fillcolor=lightgreen, label="dispatcher\n(Start)"];
#   "Researcher-Agent" [label="Researcher-Agent"];
#   "Plan-Agent" [label="Plan-Agent"];
#   "aggregator" [label="aggregator"];
#
#   "fan_in::aggregator::69d73de8" [shape=ellipse, fillcolor=lightgoldenrod, label="fan-in"];
#   "Plan-Agent" -> "fan_in::aggregator::69d73de8";
#   "Researcher-Agent" -> "fan_in::aggregator::69d73de8";
#   "fan_in::aggregator::69d73de8" -> "aggregator";
#   "dispatcher" -> "Researcher-Agent";
#   "dispatcher" -> "Plan-Agent";
# }
# =======
# SVG file saved to: /var/folders/66/m82q566n4c130x_vdtybj5b40000gn/T/tmpuhvep8a0.svg

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")
# Out:
# Attempting to display SVG file at: /var/folders/66/m82q566n4c130x_vdtybj5b40000gn/T/tmpuhvep8a0.svg

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
        print("===== Final Aggregated Conversation (messages) =====")
        for output in outputs:
            messages: list[ChatMessage] | Any = output
            for i, msg in enumerate(messages, start=1):
                name = msg.author_name if msg.author_name else "user"
                print(f"{'-' * 60}\n\n{i:02d} [{name}]:\n{msg.text}")
# Out:
# ===== Final Aggregated Conversation (messages) =====
# ------------------------------------------------------------
#
# 01 [user]:
# Plan a trip to Seattle in December
# ------------------------------------------------------------
#
# 02 [Researcher-Agent]:
# Seattle in December offers a magical combination of holiday cheer, cozy indoor activities, and a dash of outdoor winter adventure. Here's a detailed plan for your trip to Seattle with top attractions, weather considerations, and tips for making the most of your experience.
#
# ---
#
# ### **Seattle in December: Destination Overview**
# - **Weather:** Expect daytime highs around 45°F (7°C) and lows around 36°F (2°C). Rain is common, so bring waterproof gear and warm layers.
# - **Atmosphere:** The city will be lively with holiday lights, festive markets, and seasonal events. It's a great time to enjoy cozy indoor attractions, as well as occasional sunny breaks for outdoor exploration.
# - **Packing Tips:** Include a waterproof jacket, umbrella, insulated footwear, warm clothing, gloves, and a hat.
#
# ---
#
# ### **Proposed Itinerary for 4 Days/3 Nights in Seattle**
#
# #### **Day 1: Arrival and Iconic Seattle Landmarks**
# 1. **Settle into your accommodation:** Choose a central location like Downtown, Pike Place Market, or Capitol Hill for convenience.
# 2. **Visit Pike Place Market:**
#    - Explore this bustling market famous for fish throwing, artisanal shops, and delicious food.
#    - Grab a coffee at the **Original Starbucks** or a snack at the many local eateries.
#    - Don't miss the quirky **Gum Wall** nearby.
#    - Time: ~2–3 hours
# 3. **Waterfront and Seattle Great Wheel:**
#    - Stroll to the waterfront area and ride the **Seattle Great Wheel** to enjoy stunning views of Puget Sound and the city skyline.
#    - Check out local shops and galleries on the waterfront.
#    - Time: ~1.5 hours
# 4. **Dinner at a waterfront restaurant:**
#    - Recommended spots: Elliott’s Oyster House (seafood) or The Crab Pot.
#
# **Optional Evening:**
# - If it’s a clear evening, visit **Kerry Park** to see an iconic view of the city skyline, Mount Rainier (weather permitting), and holiday lights.
#
# ---
#
# #### **Day 2: Arts, Culture, and Festivities**
# 1. **Breakfast in Capitol Hill:**
#    - Try **Tilikum Place Café** or a local bakery in the trendy Capitol Hill area.
# 2. **Seattle Center: Space Needle & Museum Visits**
#    - Visit the **Space Needle** for amazing vistas (buy tickets in advance). Fog is possible in December, so go when skies are clear.
#    - Explore the fascinating museums nearby:
#      - **Chihuly Garden and Glass** for mesmerizing glass art exhibits.
#      - **Museum of Pop Culture (MoPOP)** for interactive exhibits about music, movies, and pop culture.
#    - Time: ~4–5 hours
# 3. **Holiday Festivities at Seattle Center Winterfest:**
#    - Enjoy ice skating, festive light displays, and performances at this seasonal event.
# 4. **Dinner in Queen Anne or South Lake Union:**
#    - Dining suggestions: Canlis (fine dining), The 5 Point Café (casual diner).
#
# ---
#
# #### **Day 3: Outdoors and Day Trip Options**
# 1. **Morning Excursion to Discovery Park:**
#    - Explore Seattle's largest green space with forest trails and scenic views of Puget Sound and the Olympic Mountains.
#    - Time: ~2 hours (dress warm for winter hiking!)
# 2. **Afternoon Options:**
#    - **Option 1: Woodland Park Zoo WildLanterns Event**
#      - Visit this seasonal festival featuring stunning animal-themed lantern installations.
#    - **Option 2: Snoqualmie Falls (About 30–40 minutes from Seattle)**
#      - Take a short road trip to see one of Washington's most beautiful waterfalls.
#      - Stop by **Snoqualmie Brewing Company** for a local beer if you have time.
# 3. **Evening Back in Seattle:**
#    - Return to the city for dinner. Suggestions: Tavolàta (Italian) or The Pink Door (romantic dining near Pike Place).
#
# ---
#
# #### **Day 4: Farewell Seattle**
# 1. **Museum of Flight (Optional for Aviation Enthusiasts):**
#    - Visit one of the largest air and space museums in the world, located near the airport.
#    - Time: ~2–3 hours
# 2. **Last-minute shopping or brunch:**
#    - Stop by **Seattle Premium Outlets** or look for unique holiday gifts at Pike Place Market if you missed it earlier.
# 3. **Airport Departure:**
#    - SEA-TAC Airport is about 30 minutes from downtown. Plan your travel timing accordingly.
#
# ---
#
# ### **Additional Seasonal Events and Attractions in December**
# 1. **Enchant Christmas Seattle:**
#    - A beautiful light maze, Christmas market, and ice skating at T-Mobile Park (dates may vary).
# 2. **Festival of Trees (Fairmont Olympic Hotel):**
#    - Enjoy beautifully decorated Christmas trees with holiday themes in a stunning historic venue.
# 3. **Argosy Christmas Ship Festival:**
#    - Book a spot on the Christmas Ship, a beautifully decorated vessel with onboard carolers. You can also watch from the shore at scheduled stops along Lake Washington, Puget Sound, and other waterways.
# 4. **Holiday Train Tour with the Polar Express Theme in Northwest Railway Museum:**
#    - A half-day trip to North Bend is perfect for families.
#
# ---
#
# ### **Local Tips**
# - **Transportation:** Use public transportation (buses, Light Rail, and Monorail) or rideshare services for convenience. Parking downtown can be expensive.
# - **Reservations:** Make dinner and major attraction reservations early, as holiday outings can get crowded.
# - **Photography:** December often brings soft light and occasional sunshine, perfect for moody and atmospheric photos of Seattle.
#
# Enjoy your trip to the Emerald City during this magical time of year!
# ------------------------------------------------------------
#
# 03 [Plan-Agent]:
# ### Travel Plan for a Winter Trip to Seattle in December
#
# Seattle is a fantastic destination in December, offering a mix of holiday festivities, iconic attractions, cozy indoor experiences, and stunning natural scenery. Being prepared for chilly weather, rain, and festive cheer will make your trip unforgettable.
#
# ---
#
# #### **Day 1: Arrival and Sightseeing in Downtown**
# **Morning: Arrival in Seattle**
# - **Airport:** Seattle-Tacoma International Airport (SEA).
# - Transportation to downtown Seattle:
#   - *Option 1*: Link Light Rail (Approx. $3, 40 minutes to downtown).
#   - *Option 2*: Taxi/Uber/Lyft (Approx. $50, 20-30 minutes).
#
# **Afternoon: Pike Place Market**
# - Explore **Pike Place Market**, one of Seattle's must-visit landmarks, beautifully decked out in holiday decorations this time of year.
# - Visit the original **Starbucks Coffee shop** and grab a warm beverage.
# - Watch fishmongers toss fish, and buy some local artisanal gifts.
#
# **Evening: Waterfront Stroll**
# - Head to **Seattle Waterfront** for breathtaking views of Elliott Bay.
# - Visit **Ye Olde Curiosity Shop**, a quirky curiosity store.
# - Dinner suggestion: **Elliott’s Oyster House** for fantastic seafood.
# - Optional: Ride the **Seattle Great Wheel** for stunning nighttime views.
#
# ---
#
# #### **Day 2: Iconic Seattle Highlights**
# **Morning: Space Needle & Chihuly Garden**
# - Visit the **Space Needle** (book tickets online to skip the line). Enjoy panoramic views of the city surrounded by wintry mountains.
# - Walk over to the **Chihuly Garden and Glass Museum** to marvel at the stunning glass art displays.
#
# **Lunch:** Have lunch at the **Collections Café** in the Space Needle's visitor center or a nearby café.
#
# **Afternoon: Museum of Pop Culture (MoPOP)**
# - Immerse yourself in Seattle’s vibrant music, film, and culture at **MoPOP** (bonus: this is a warm indoor activity, perfect for winter weather).
# - If you're into shopping or need more warmth, explore **Pacific Place Mall** downtown.
#
# **Evening: Holiday Lights Event**
# - Head to **Westlake Park** or **Seattle Center** to see holiday lights.
# - Dinner suggestion: **The Pink Door**, an Italian-American restaurant near Pike Place Market offering intimate, cozy vibes.
#
# ---
#
# #### **Day 3: Outdoor Adventures & Lake Union**
# **Morning: Discovery Park**
# - Bundle up and venture to **Discovery Park**, Seattle’s largest green space, for a winter walk and views of the Puget Sound.
#
# **Lunch:** Visit **The 5 Point Café**, a retro diner with comfort food favorites.
#
# **Afternoon: Lake Union Winter Boating**
# - Rent a **hot tub boat** or take a cozy electric boat and cruise on **Lake Union** while taking in views of the houseboats, including the one from the movie *Sleepless in Seattle*!
# - Visit the **Museum of History & Industry (MOHAI)** located along the lake to learn about Seattle's fascinating history.
#
# **Evening: Cozy Brewery Experience**
# - Visit Seattle's craft breweries to warm up. Recommendations:
#   - **Fremont Brewing Company** (outdoor fire pits).
#   - **Optimism Brewing Company** near Capitol Hill.
#
# ---
#
# #### **Day 4: Day Trip to Snoqualmie Falls or Leavenworth**
# **Option 1: Snoqualmie Falls (Half-Day Trip)**
# - About a 35-minute drive from Seattle, visit the stunning **Snoqualmie Falls**, often framed with snow in December.
# - Warm up at the **Salish Lodge** for brunch beside fireplaces with scenic views.
#
# **Option 2: Leavenworth (Full-Day Trip)**
# - Take a 2-hour scenic drive to **Leavenworth**, the Bavarian-style village. During December, it’s transformed into a winter wonderland with holiday lights, festive shops, and horse-drawn sleigh rides.
# - Enjoy German food and mulled wine at **Andreas Keller**.
#
# ---
#
# #### **Day 5: Capitol Hill & Departure**
# **Morning: Capitol Hill Exploration**
# - Explore the hip and trendy **Capitol Hill** neighborhood. Don’t miss:
#   - Brunch at **Tilikum Place Café** (known for Dutch pancakes).
#   - Visit **Elliott Bay Book Company**, one of Seattle’s best indie bookstores.
#   - Walk through **Volunteer Park Conservatory**, a lush indoor escape from the cold.
#
# **Afternoon:** Begin your return journey to the airport.
# - Stop by **Beecher’s Handmade Cheese** in Pike Place Market to pick up snacks before leaving.
#
# ---
#
# ### **Accommodation Options**
# 1. **Luxury:**
#    - Thompson Seattle (Stunning views + central location).
#    - The Four Seasons Seattle (Upscale amenities near downtown).
#
# 2. **Midrange:**
#    - The Hotel Andra (Boutique hotel with cozy Scandinavian vibes).
#    - The Maxwell Hotel by Staypineapple.
#
# 3. **Budget:**
#    - Green Tortoise Hostel (Great location near the market).
#    - Belltown Inn (Functional and budget-friendly).
#
# ---
#
# ### **Packing Tips**
# - Bring a waterproof jacket and shoes (Seattle is notorious for rainy winters).
# - Pack warm layers, including sweaters, scarves, gloves, and a hat.
# - An umbrella can be handy, but locals often opt for water-resistant clothing instead.
#
# ---
#
# ### **Transportation Tips**
# - Use public transit like the **Seattle Streetcar**, buses, or **Link Light Rail** for easy and eco-friendly transport.
# - Consider ride-shares or car rentals if opting for day trips outside the city.
#
# Seattle in December has something for everyone, from holiday festivities and cozy indoor activities to outdoor winter adventures. Let me know if you'd like to fine-tune this itinerary!
